# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
import openweathermapy.core as owm
import openweathermapy as ow
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %%
cities_df = pd.DataFrame(cities)

# %%
cities_df.columns = ['City']
cities_df.head()
# Out:
#            City
# 0       rikitea
# 1  constitucion
# 2       ushuaia
# 3     bathsheba
# 4       florida

# %%
export_csv = cities_df.to_csv('output_data/cities.csv', encoding='utf-8', index=False)

# %%
cities_dft = pd.read_csv('output_data/cities.csv')
cities_dft.head()
# Out:
#            City
# 0       rikitea
# 1  constitucion
# 2       ushuaia
# 3     bathsheba
# 4       florida

# %%
cities_dft.reset_index(drop=True, inplace=True)

# %%
settings = {"appid": api_key, "units": "metric"}

# %%
units = ["metric"]

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
query_url = url + "appid=" + api_key + "&q=" + city

# %%
print(requests.get(query_url))
# Out:
# <Response [200]>

# %%
keys = ["clouds.all", "sys.country", "dt", "main.temp", "main.humidity", "coord.lat", "coord.lon", "main.temp_max", "wind.speed"]

# %%
n = 0
#keys = ["clouds.all", "sys.country", "dt", "main.temp", "main.humidity", "coord.lat", "coord.lon", "main.temp_max", "wind.speed"]
weather_data = []
response_json = []
for index, row in cities_df.iterrows():
    n += 1
    time.sleep(1)
    weather_data.append(owm.find_city(row[0], **settings))
    response_json.append(weather_data)
    print(f"City number {n} is, {row}")
#time.sleep(1)
    #if weather_data['cod'] == "404":
        #print(f"City, is not available")
# Out:
# City number 1 is, City    rikitea
# Name: 0, dtype: object
# City number 2 is, City    constitucion
# Name: 1, dtype: object
# City number 3 is, City    ushuaia
# Name: 2, dtype: object
# City number 4 is, City    bathsheba
# Name: 3, dtype: object
# City number 5 is, City    florida
# Name: 4, dtype: object
# City number 6 is, City    tuktoyaktuk
# Name: 5, dtype: object
# City number 7 is, City    marsberg
# Name: 6, dtype: object
# City number 8 is, City    cidreira
# Name: 7, dtype: object
# City number 9 is, City    kapaa
# Name: 8, dtype: object
# City number 10 is, City    bluff
# Name: 9, dtype: object
# City number 11 is, City    barrow
# Name: 10, dtype: object
# City number 12 is, City    mitsamiouli
# Name: 11, dtype: object
# City number 13 is, City    saskylakh
# Name: 12, dtype: object
# City number 14 is, City    sorland
# Name: 13, dtype: object
# City number 15 is, City    hermanus
# Name: 14, dtype: object
# City number 16 is, City    mataura
# Name: 15, dtype: object
# City number 17 is, City    sur
# Name: 16, dtype: object
# City number 18 is, City    saleaula
# Name: 17, dtype: object
# City number 19 is, City    tasiilaq
# Name: 18, dtype: object
# City number 20 is, City    itarema
# Name: 19, dtype: object
# City number 21 is, City    fairbanks
# Name: 20, dtype: object
# City number 22 is, City    hobart
# Name: 21, dtype: object
# City number 23 is, City    severo-kurilsk
# Name: 22, dtype: object
# City number 24 is, City    vila velha
# Name: 23, dtype: object
# City number 25 is, City    illoqqortoormiut
# Name: 24, dtype: object
# City number 26 is, City    presidencia roque saenz pena
# Name: 25, dtype: object
# City number 27 is, City    hilo
# Name: 26, dtype: object
# City number 28 is, City    daxian
# Name: 27, dtype: object
# City number 29 is, City    tokzar
# Name: 28, dtype: object
# City number 30 is, City    kaitangata
# Name: 29, dtype: object
# City number 31 is, City    guarapari
# Name: 30, dtype: object
# City number 32 is, City    fortuna
# Name: 31, dtype: object
# City number 33 is, City    kargil
# Name: 32, dtype: object
# City number 34 is, City    listvyanskiy
# Name: 33, dtype: object
# City number 35 is, City    selfoss
# Name: 34, dtype: object
# City number 36 is, City    mount gambier
# Name: 35, dtype: object
# City number 37 is, City    atar
# Name: 36, dtype: object
# City number 38 is, City    maghama
# Name: 37, dtype: object
# City number 39 is, City    saint-joseph
# Name: 38, dtype: object
# City number 40 is, City    arraial do cabo
# Name: 39, dtype: object
# City number 41 is, City    karratha
# Name: 40, dtype: object
# City number 42 is, City    konongo
# Name: 41, dtype: object
# City number 43 is, City    georgetown
# Name: 42, dtype: object
# City number 44 is, City    villazon
# Name: 43, dtype: object
# City number 45 is, City    boa vista
# Name: 44, dtype: object
# City number 46 is, City    xam nua
# Name: 45, dtype: object
# City number 47 is, City    qaanaaq
# Name: 46, dtype: object
# City number 48 is, City    mar del plata
# Name: 47, dtype: object
# City number 49 is, City    hamamatsu
# Name: 48, dtype: object
# City number 50 is, City    buenaventura
# Name: 49, dtype: object
# City number 51 is, City    talnakh
# Name: 50, dtype: object
# City number 52 is, City    vaini
# Name: 51, dtype: object
# City number 53 is, City    cherskiy
# Name: 52, dtype: object
# City number 54 is, City    agadez
# Name: 53, dtype: object
# City number 55 is, City    lompoc
# Name: 54, dtype: object
# City number 56 is, City    punta arenas
# Name: 55, dtype: object
# City number 57 is, City    coahuayana
# Name: 56, dtype: object
# City number 58 is, City    barentsburg
# Name: 57, dtype: object
# City number 59 is, City    paradwip
# Name: 58, dtype: object
# City number 60 is, City    saldanha
# Name: 59, dtype: object
# City number 61 is, City    praia da vitoria
# Name: 60, dtype: object
# City number 62 is, City    papasquiaro
# Name: 61, dtype: object
# City number 63 is, City    burnie
# Name: 62, dtype: object
# City number 64 is, City    saint-philippe
# Name: 63, dtype: object
# City number 65 is, City    shuyskoye
# Name: 64, dtype: object
# City number 66 is, City    kytlym
# Name: 65, dtype: object
# City number 67 is, City    hokitika
# Name: 66, dtype: object
# City number 68 is, City    marcona
# Name: 67, dtype: object
# City number 69 is, City    east london
# Name: 68, dtype: object
# City number 70 is, City    katsuura
# Name: 69, dtype: object
# City number 71 is, City    gushikawa
# Name: 70, dtype: object
# City number 72 is, City    thibodaux
# Name: 71, dtype: object
# City number 73 is, City    puerto ayacucho
# Name: 72, dtype: object
# City number 74 is, City    amderma
# Name: 73, dtype: object
# City number 75 is, City    castro
# Name: 74, dtype: object
# City number 76 is, City    faanui
# Name: 75, dtype: object
# City number 77 is, City    bulaevo
# Name: 76, dtype: object
# City number 78 is, City    bredasdorp
# Name: 77, dtype: object
# City number 79 is, City    mongoumba
# Name: 78, dtype: object
# City number 80 is, City    san vicente
# Name: 79, dtype: object
# City number 81 is, City    atyrau
# Name: 80, dtype: object
# City number 82 is, City    matara
# Name: 81, dtype: object
# City number 83 is, City    souillac
# Name: 82, dtype: object
# City number 84 is, City    linqu
# Name: 83, dtype: object
# City number 85 is, City    wenatchee
# Name: 84, dtype: object
# City number 86 is, City    port blair
# Name: 85, dtype: object
# City number 87 is, City    jamestown
# Name: 86, dtype: object
# City number 88 is, City    yumen
# Name: 87, dtype: object
# City number 89 is, City    hamilton
# Name: 88, dtype: object
# City number 90 is, City    chokurdakh
# Name: 89, dtype: object
# City number 91 is, City    rawson
# Name: 90, dtype: object
# City number 92 is, City    margate
# Name: 91, dtype: object
# City number 93 is, City    codrington
# Name: 92, dtype: object
# City number 94 is, City    berdigestyakh
# Name: 93, dtype: object
# City number 95 is, City    sentyabrskiy
# Name: 94, dtype: object
# City number 96 is, City    gat
# Name: 95, dtype: object
# City number 97 is, City    padang
# Name: 96, dtype: object
# City number 98 is, City    cape town
# Name: 97, dtype: object
# City number 99 is, City    avarua
# Name: 98, dtype: object
# City number 100 is, City    odweyne
# Name: 99, dtype: object
# City number 101 is, City    mahibadhoo
# Name: 100, dtype: object
# City number 102 is, City    nishihara
# Name: 101, dtype: object
# City number 103 is, City    la union
# Name: 102, dtype: object
# City number 104 is, City    banda aceh
# Name: 103, dtype: object
# City number 105 is, City    kodiak
# Name: 104, dtype: object
# City number 106 is, City    lolua
# Name: 105, dtype: object
# City number 107 is, City    nizhneyansk
# Name: 106, dtype: object
# City number 108 is, City    morant bay
# Name: 107, dtype: object
# City number 109 is, City    port moresby
# Name: 108, dtype: object
# City number 110 is, City    victoria
# Name: 109, dtype: object
# City number 111 is, City    thompson
# Name: 110, dtype: object
# City number 112 is, City    puerto ayora
# Name: 111, dtype: object
# City number 113 is, City    atuona
# Name: 112, dtype: object
# City number 114 is, City    mahebourg
# Name: 113, dtype: object
# City number 115 is, City    mys shmidta
# Name: 114, dtype: object
# City number 116 is, City    ahipara
# Name: 115, dtype: object
# City number 117 is, City    busselton
# Name: 116, dtype: object
# City number 118 is, City    pevek
# Name: 117, dtype: object
# City number 119 is, City    new norfolk
# Name: 118, dtype: object
# City number 120 is, City    mergui
# Name: 119, dtype: object
# City number 121 is, City    tiksi
# Name: 120, dtype: object
# City number 122 is, City    naze
# Name: 121, dtype: object
# City number 123 is, City    necochea
# Name: 122, dtype: object
# City number 124 is, City    ola
# Name: 123, dtype: object
# City number 125 is, City    bafoulabe
# Name: 124, dtype: object
# City number 126 is, City    qui nhon
# Name: 125, dtype: object
# City number 127 is, City    weston
# Name: 126, dtype: object
# City number 128 is, City    pascagoula
# Name: 127, dtype: object
# City number 129 is, City    kuvshinovo
# Name: 128, dtype: object
# City number 130 is, City    nikolskoye
# Name: 129, dtype: object
# City number 131 is, City    dauriya
# Name: 130, dtype: object
# City number 132 is, City    salalah
# Name: 131, dtype: object
# City number 133 is, City    taolanaro
# Name: 132, dtype: object
# City number 134 is, City    bamako
# Name: 133, dtype: object
# City number 135 is, City    ribeira grande
# Name: 134, dtype: object
# City number 136 is, City    los llanos de aridane
# Name: 135, dtype: object
# City number 137 is, City    toowoomba
# Name: 136, dtype: object
# City number 138 is, City    sao filipe
# Name: 137, dtype: object
# City number 139 is, City    qaqortoq
# Name: 138, dtype: object
# City number 140 is, City    vardo
# Name: 139, dtype: object
# City number 141 is, City    chifeng
# Name: 140, dtype: object
# City number 142 is, City    marana
# Name: 141, dtype: object
# City number 143 is, City    pisco
# Name: 142, dtype: object
# City number 144 is, City    bethel
# Name: 143, dtype: object
# City number 145 is, City    srednekolymsk
# Name: 144, dtype: object
# City number 146 is, City    atambua
# Name: 145, dtype: object
# City number 147 is, City    kavaratti
# Name: 146, dtype: object
# City number 148 is, City    muros
# Name: 147, dtype: object
# City number 149 is, City    dawei
# Name: 148, dtype: object
# City number 150 is, City    lucea
# Name: 149, dtype: object
# City number 151 is, City    berezovyy
# Name: 150, dtype: object
# City number 152 is, City    urumqi
# Name: 151, dtype: object
# City number 153 is, City    port elizabeth
# Name: 152, dtype: object
# City number 154 is, City    paamiut
# Name: 153, dtype: object
# City number 155 is, City    nome
# Name: 154, dtype: object
# City number 156 is, City    naberera
# Name: 155, dtype: object
# City number 157 is, City    ukiah
# Name: 156, dtype: object
# City number 158 is, City    san andres
# Name: 157, dtype: object
# City number 159 is, City    khatanga
# Name: 158, dtype: object
# City number 160 is, City    norman wells
# Name: 159, dtype: object
# City number 161 is, City    mtwara
# Name: 160, dtype: object
# City number 162 is, City    ilula
# Name: 161, dtype: object
# City number 163 is, City    tautira
# Name: 162, dtype: object
# City number 164 is, City    grindavik
# Name: 163, dtype: object
# City number 165 is, City    dolores
# Name: 164, dtype: object
# City number 166 is, City    dakoro
# Name: 165, dtype: object
# City number 167 is, City    clonakilty
# Name: 166, dtype: object
# City number 168 is, City    derzhavinsk
# Name: 167, dtype: object
# City number 169 is, City    upernavik
# Name: 168, dtype: object
# City number 170 is, City    port alfred
# Name: 169, dtype: object
# City number 171 is, City    scottsburgh
# Name: 170, dtype: object
# City number 172 is, City    aras
# Name: 171, dtype: object
# City number 173 is, City    doba
# Name: 172, dtype: object
# City number 174 is, City    dhidhdhoo
# Name: 173, dtype: object
# City number 175 is, City    mouila
# Name: 174, dtype: object
# City number 176 is, City    lata
# Name: 175, dtype: object
# City number 177 is, City    dikson
# Name: 176, dtype: object
# City number 178 is, City    carnarvon
# Name: 177, dtype: object
# City number 179 is, City    samusu
# Name: 178, dtype: object
# City number 180 is, City    leningradskiy
# Name: 179, dtype: object
# City number 181 is, City    hithadhoo
# Name: 180, dtype: object
# City number 182 is, City    kaeo
# Name: 181, dtype: object
# City number 183 is, City    mehamn
# Name: 182, dtype: object
# City number 184 is, City    gornyye klyuchi
# Name: 183, dtype: object
# City number 185 is, City    saint george
# Name: 184, dtype: object
# City number 186 is, City    hasaki
# Name: 185, dtype: object
# City number 187 is, City    albany
# Name: 186, dtype: object
# City number 188 is, City    kloulklubed
# Name: 187, dtype: object
# City number 189 is, City    susangerd
# Name: 188, dtype: object
# City number 190 is, City    atherton
# Name: 189, dtype: object
# City number 191 is, City    cabo san lucas
# Name: 190, dtype: object
# City number 192 is, City    alekseyevsk
# Name: 191, dtype: object
# City number 193 is, City    vaitupu
# Name: 192, dtype: object
# City number 194 is, City    yellowknife
# Name: 193, dtype: object
# City number 195 is, City    chuy
# Name: 194, dtype: object
# City number 196 is, City    bambous virieux
# Name: 195, dtype: object
# City number 197 is, City    nizwa
# Name: 196, dtype: object
# City number 198 is, City    mocuba
# Name: 197, dtype: object
# City number 199 is, City    luderitz
# Name: 198, dtype: object
# City number 200 is, City    aripuana
# Name: 199, dtype: object
# City number 201 is, City    svobodnyy
# Name: 200, dtype: object
# City number 202 is, City    dera gopipur
# Name: 201, dtype: object
# City number 203 is, City    goderich
# Name: 202, dtype: object
# City number 204 is, City    luoyang
# Name: 203, dtype: object
# City number 205 is, City    tilichiki
# Name: 204, dtype: object
# City number 206 is, City    kharp
# Name: 205, dtype: object
# City number 207 is, City    merritt island
# Name: 206, dtype: object
# City number 208 is, City    dzhebariki-khaya
# Name: 207, dtype: object
# City number 209 is, City    meulaboh
# Name: 208, dtype: object
# City number 210 is, City    umzimvubu
# Name: 209, dtype: object
# City number 211 is, City    hay river
# Name: 210, dtype: object
# City number 212 is, City    mahadday weyne
# Name: 211, dtype: object
# City number 213 is, City    zhigansk
# Name: 212, dtype: object
# City number 214 is, City    taunggyi
# Name: 213, dtype: object
# City number 215 is, City    kresttsy
# Name: 214, dtype: object
# City number 216 is, City    lydenburg
# Name: 215, dtype: object
# City number 217 is, City    bad tolz
# Name: 216, dtype: object
# City number 218 is, City    college
# Name: 217, dtype: object
# City number 219 is, City    vao
# Name: 218, dtype: object
# City number 220 is, City    tessalit
# Name: 219, dtype: object
# City number 221 is, City    moussoro
# Name: 220, dtype: object
# City number 222 is, City    albion
# Name: 221, dtype: object
# City number 223 is, City    itoman
# Name: 222, dtype: object
# City number 224 is, City    wewak
# Name: 223, dtype: object
# City number 225 is, City    plock
# Name: 224, dtype: object
# City number 226 is, City    fallon
# Name: 225, dtype: object
# City number 227 is, City    axim
# Name: 226, dtype: object
# City number 228 is, City    seka
# Name: 227, dtype: object
# City number 229 is, City    sitka
# Name: 228, dtype: object
# City number 230 is, City    belushya guba
# Name: 229, dtype: object
# City number 231 is, City    guerrero negro
# Name: 230, dtype: object
# City number 232 is, City    brae
# Name: 231, dtype: object
# City number 233 is, City    mahanje
# Name: 232, dtype: object
# City number 234 is, City    cockburn town
# Name: 233, dtype: object
# City number 235 is, City    kyabram
# Name: 234, dtype: object
# City number 236 is, City    along
# Name: 235, dtype: object
# City number 237 is, City    shache
# Name: 236, dtype: object
# City number 238 is, City    imbituba
# Name: 237, dtype: object
# City number 239 is, City    klaksvik
# Name: 238, dtype: object
# City number 240 is, City    arivonimamo
# Name: 239, dtype: object
# City number 241 is, City    amapa
# Name: 240, dtype: object
# City number 242 is, City    volkhov
# Name: 241, dtype: object
# City number 243 is, City    soe
# Name: 242, dtype: object
# City number 244 is, City    cabedelo
# Name: 243, dtype: object
# City number 245 is, City    port macquarie
# Name: 244, dtype: object
# City number 246 is, City    tezu
# Name: 245, dtype: object
# City number 247 is, City    poum
# Name: 246, dtype: object
# City number 248 is, City    zorgo
# Name: 247, dtype: object
# City number 249 is, City    hambantota
# Name: 248, dtype: object
# City number 250 is, City    khormuj
# Name: 249, dtype: object
# City number 251 is, City    tshela
# Name: 250, dtype: object
# City number 252 is, City    aleksandrov gay
# Name: 251, dtype: object
# City number 253 is, City    kruisfontein
# Name: 252, dtype: object
# City number 254 is, City    kalabo
# Name: 253, dtype: object
# City number 255 is, City    muravlenko
# Name: 254, dtype: object
# City number 256 is, City    rongcheng
# Name: 255, dtype: object
# City number 257 is, City    attawapiskat
# Name: 256, dtype: object
# City number 258 is, City    ormara
# Name: 257, dtype: object
# City number 259 is, City    beringovskiy
# Name: 258, dtype: object
# City number 260 is, City    libreville
# Name: 259, dtype: object
# City number 261 is, City    mercedes
# Name: 260, dtype: object
# City number 262 is, City    oriximina
# Name: 261, dtype: object
# City number 263 is, City    suriapet
# Name: 262, dtype: object
# City number 264 is, City    torbay
# Name: 263, dtype: object
# City number 265 is, City    tura
# Name: 264, dtype: object
# City number 266 is, City    north myrtle beach
# Name: 265, dtype: object
# City number 267 is, City    pacific grove
# Name: 266, dtype: object
# City number 268 is, City    nouadhibou
# Name: 267, dtype: object
# City number 269 is, City    birao
# Name: 268, dtype: object
# City number 270 is, City    alekseyevka
# Name: 269, dtype: object
# City number 271 is, City    kollo
# Name: 270, dtype: object
# City number 272 is, City    yerbogachen
# Name: 271, dtype: object
# City number 273 is, City    hurricane
# Name: 272, dtype: object
# City number 274 is, City    altamont
# Name: 273, dtype: object
# City number 275 is, City    road town
# Name: 274, dtype: object
# City number 276 is, City    karatau
# Name: 275, dtype: object
# City number 277 is, City    flin flon
# Name: 276, dtype: object
# City number 278 is, City    linqiong
# Name: 277, dtype: object
# City number 279 is, City    sao joao da barra
# Name: 278, dtype: object
# City number 280 is, City    novikovo
# Name: 279, dtype: object
# City number 281 is, City    bilma
# Name: 280, dtype: object
# City number 282 is, City    ambon
# Name: 281, dtype: object
# City number 283 is, City    ngukurr
# Name: 282, dtype: object
# City number 284 is, City    iqaluit
# Name: 283, dtype: object
# City number 285 is, City    maniitsoq
# Name: 284, dtype: object
# City number 286 is, City    wajima
# Name: 285, dtype: object
# City number 287 is, City    touros
# Name: 286, dtype: object
# City number 288 is, City    hualmay
# Name: 287, dtype: object
# City number 289 is, City    sioux lookout
# Name: 288, dtype: object
# City number 290 is, City    deputatskiy
# Name: 289, dtype: object
# City number 291 is, City    belmopan
# Name: 290, dtype: object
# City number 292 is, City    kismayo
# Name: 291, dtype: object
# City number 293 is, City    lagoa
# Name: 292, dtype: object
# City number 294 is, City    shingu
# Name: 293, dtype: object
# City number 295 is, City    rio grande
# Name: 294, dtype: object
# City number 296 is, City    dekar
# Name: 295, dtype: object
# City number 297 is, City    zapolyarnyy
# Name: 296, dtype: object
# City number 298 is, City    tokmak
# Name: 297, dtype: object
# City number 299 is, City    paidha
# Name: 298, dtype: object
# City number 300 is, City    butaritari
# Name: 299, dtype: object
# City number 301 is, City    kingman
# Name: 300, dtype: object
# City number 302 is, City    glendive
# Name: 301, dtype: object
# City number 303 is, City    berezniki
# Name: 302, dtype: object
# City number 304 is, City    ndola
# Name: 303, dtype: object
# City number 305 is, City    ploemeur
# Name: 304, dtype: object
# City number 306 is, City    koslan
# Name: 305, dtype: object
# City number 307 is, City    letlhakeng
# Name: 306, dtype: object
# City number 308 is, City    richards bay
# Name: 307, dtype: object
# City number 309 is, City    lakselv
# Name: 308, dtype: object
# City number 310 is, City    mount isa
# Name: 309, dtype: object
# City number 311 is, City    washington
# Name: 310, dtype: object
# City number 312 is, City    yenagoa
# Name: 311, dtype: object
# City number 313 is, City    avera
# Name: 312, dtype: object
# City number 314 is, City    nanortalik
# Name: 313, dtype: object
# City number 315 is, City    vanimo
# Name: 314, dtype: object
# City number 316 is, City    oussouye
# Name: 315, dtype: object
# City number 317 is, City    haines junction
# Name: 316, dtype: object
# City number 318 is, City    fayetteville
# Name: 317, dtype: object
# City number 319 is, City    esperance
# Name: 318, dtype: object
# City number 320 is, City    baraboo
# Name: 319, dtype: object
# City number 321 is, City    longyearbyen
# Name: 320, dtype: object
# City number 322 is, City    provideniya
# Name: 321, dtype: object
# City number 323 is, City    vestmannaeyjar
# Name: 322, dtype: object
# City number 324 is, City    ancud
# Name: 323, dtype: object
# City number 325 is, City    chapais
# Name: 324, dtype: object
# City number 326 is, City    svetlogorsk
# Name: 325, dtype: object
# City number 327 is, City    geraldton
# Name: 326, dtype: object
# City number 328 is, City    nova odesa
# Name: 327, dtype: object
# City number 329 is, City    tiznit
# Name: 328, dtype: object
# City number 330 is, City    roald
# Name: 329, dtype: object
# City number 331 is, City    namibe
# Name: 330, dtype: object
# City number 332 is, City    weihe
# Name: 331, dtype: object
# City number 333 is, City    airai
# Name: 332, dtype: object
# City number 334 is, City    macenta
# Name: 333, dtype: object
# City number 335 is, City    panaba
# Name: 334, dtype: object
# City number 336 is, City    marawi
# Name: 335, dtype: object
# City number 337 is, City    manokwari
# Name: 336, dtype: object
# City number 338 is, City    suzhou
# Name: 337, dtype: object
# City number 339 is, City    great falls
# Name: 338, dtype: object
# City number 340 is, City    turkmenabat
# Name: 339, dtype: object
# City number 341 is, City    lebu
# Name: 340, dtype: object
# City number 342 is, City    santa maria
# Name: 341, dtype: object
# City number 343 is, City    havoysund
# Name: 342, dtype: object
# City number 344 is, City    mvuma
# Name: 343, dtype: object
# City number 345 is, City    shihezi
# Name: 344, dtype: object
# City number 346 is, City    bahir dar
# Name: 345, dtype: object
# City number 347 is, City    gabu
# Name: 346, dtype: object
# City number 348 is, City    nosy varika
# Name: 347, dtype: object
# City number 349 is, City    sovetskiy
# Name: 348, dtype: object
# City number 350 is, City    kodra
# Name: 349, dtype: object
# City number 351 is, City    puerto del rosario
# Name: 350, dtype: object
# City number 352 is, City    baykit
# Name: 351, dtype: object
# City number 353 is, City    alotau
# Name: 352, dtype: object
# City number 354 is, City    tondano
# Name: 353, dtype: object
# City number 355 is, City    tiruvottiyur
# Name: 354, dtype: object
# City number 356 is, City    san quintin
# Name: 355, dtype: object
# City number 357 is, City    kijang
# Name: 356, dtype: object
# City number 358 is, City    kerema
# Name: 357, dtype: object
# City number 359 is, City    tawkar
# Name: 358, dtype: object
# City number 360 is, City    asmara
# Name: 359, dtype: object
# City number 361 is, City    rodrigues alves
# Name: 360, dtype: object
# City number 362 is, City    biak
# Name: 361, dtype: object
# City number 363 is, City    berlevag
# Name: 362, dtype: object
# City number 364 is, City    port-gentil
# Name: 363, dtype: object
# City number 365 is, City    tanete
# Name: 364, dtype: object
# City number 366 is, City    toktogul
# Name: 365, dtype: object
# City number 367 is, City    qasigiannguit
# Name: 366, dtype: object
# City number 368 is, City    labuhan
# Name: 367, dtype: object
# City number 369 is, City    rovaniemi
# Name: 368, dtype: object
# City number 370 is, City    narsaq
# Name: 369, dtype: object
# City number 371 is, City    tuatapere
# Name: 370, dtype: object
# City number 372 is, City    nabire
# Name: 371, dtype: object
# City number 373 is, City    sakakah
# Name: 372, dtype: object
# City number 374 is, City    bandarbeyla
# Name: 373, dtype: object
# City number 375 is, City    faya
# Name: 374, dtype: object
# City number 376 is, City    kalmunai
# Name: 375, dtype: object
# City number 377 is, City    coihaique
# Name: 376, dtype: object
# City number 378 is, City    kiruna
# Name: 377, dtype: object
# City number 379 is, City    lere
# Name: 378, dtype: object
# City number 380 is, City    pauini
# Name: 379, dtype: object
# City number 381 is, City    dolbeau
# Name: 380, dtype: object
# City number 382 is, City    cassilandia
# Name: 381, dtype: object
# City number 383 is, City    beeville
# Name: 382, dtype: object
# City number 384 is, City    antofagasta
# Name: 383, dtype: object
# City number 385 is, City    caravelas
# Name: 384, dtype: object
# City number 386 is, City    koshurnikovo
# Name: 385, dtype: object
# City number 387 is, City    jaramana
# Name: 386, dtype: object
# City number 388 is, City    pangai
# Name: 387, dtype: object
# City number 389 is, City    pousat
# Name: 388, dtype: object
# City number 390 is, City    bengkulu
# Name: 389, dtype: object
# City number 391 is, City    tinyahuarco
# Name: 390, dtype: object
# City number 392 is, City    manavalakurichi
# Name: 391, dtype: object
# City number 393 is, City    lanxi
# Name: 392, dtype: object
# City number 394 is, City    ewa beach
# Name: 393, dtype: object
# City number 395 is, City    eskil
# Name: 394, dtype: object
# City number 396 is, City    slavjanovo
# Name: 395, dtype: object
# City number 397 is, City    zile
# Name: 396, dtype: object
# City number 398 is, City    dera ghazi khan
# Name: 397, dtype: object
# City number 399 is, City    svetlyy
# Name: 398, dtype: object
# City number 400 is, City    half moon bay
# Name: 399, dtype: object
# City number 401 is, City    batangafo
# Name: 400, dtype: object
# City number 402 is, City    la asuncion
# Name: 401, dtype: object
# City number 403 is, City    tabasco
# Name: 402, dtype: object
# City number 404 is, City    pozo colorado
# Name: 403, dtype: object
# City number 405 is, City    raudeberg
# Name: 404, dtype: object
# City number 406 is, City    kuala terengganu
# Name: 405, dtype: object
# City number 407 is, City    nanakuli
# Name: 406, dtype: object
# City number 408 is, City    santa cruz de la palma
# Name: 407, dtype: object
# City number 409 is, City    fengcheng
# Name: 408, dtype: object
# City number 410 is, City    saint-augustin
# Name: 409, dtype: object
# City number 411 is, City    barreirinhas
# Name: 410, dtype: object
# City number 412 is, City    young
# Name: 411, dtype: object
# City number 413 is, City    celestun
# Name: 412, dtype: object
# City number 414 is, City    harper
# Name: 413, dtype: object
# City number 415 is, City    maxixe
# Name: 414, dtype: object
# City number 416 is, City    lasa
# Name: 415, dtype: object
# City number 417 is, City    aasiaat
# Name: 416, dtype: object
# City number 418 is, City    gualaquiza
# Name: 417, dtype: object
# City number 419 is, City    ghatsila
# Name: 418, dtype: object
# City number 420 is, City    norden
# Name: 419, dtype: object
# City number 421 is, City    bubaque
# Name: 420, dtype: object
# City number 422 is, City    roma
# Name: 421, dtype: object
# City number 423 is, City    ruteng
# Name: 422, dtype: object
# City number 424 is, City    dunedin
# Name: 423, dtype: object
# City number 425 is, City    nemuro
# Name: 424, dtype: object
# City number 426 is, City    barda
# Name: 425, dtype: object
# City number 427 is, City    jinchengjiang
# Name: 426, dtype: object
# City number 428 is, City    fare
# Name: 427, dtype: object
# City number 429 is, City    petropavlovsk-kamchatskiy
# Name: 428, dtype: object
# City number 430 is, City    poya
# Name: 429, dtype: object
# City number 431 is, City    honningsvag
# Name: 430, dtype: object
# City number 432 is, City    toliary
# Name: 431, dtype: object
# City number 433 is, City    sibolga
# Name: 432, dtype: object
# City number 434 is, City    tagusao
# Name: 433, dtype: object
# City number 435 is, City    vernon
# Name: 434, dtype: object
# City number 436 is, City    obihiro
# Name: 435, dtype: object
# City number 437 is, City    dukat
# Name: 436, dtype: object
# City number 438 is, City    nea alikarnassos
# Name: 437, dtype: object
# City number 439 is, City    liseleje
# Name: 438, dtype: object
# City number 440 is, City    wad rawah
# Name: 439, dtype: object
# City number 441 is, City    pachino
# Name: 440, dtype: object
# City number 442 is, City    prokuplje
# Name: 441, dtype: object
# City number 443 is, City    yirol
# Name: 442, dtype: object
# City number 444 is, City    tsihombe
# Name: 443, dtype: object
# City number 445 is, City    beloha
# Name: 444, dtype: object
# City number 446 is, City    andros town
# Name: 445, dtype: object
# City number 447 is, City    kahului
# Name: 446, dtype: object
# City number 448 is, City    selam
# Name: 447, dtype: object
# City number 449 is, City    lunel
# Name: 448, dtype: object
# City number 450 is, City    ginda
# Name: 449, dtype: object
# City number 451 is, City    san patricio
# Name: 450, dtype: object
# City number 452 is, City    chinsali
# Name: 451, dtype: object
# City number 453 is, City    simao
# Name: 452, dtype: object
# City number 454 is, City    lolodorf
# Name: 453, dtype: object
# City number 455 is, City    sorsk
# Name: 454, dtype: object
# City number 456 is, City    ballina
# Name: 455, dtype: object
# City number 457 is, City    kerouane
# Name: 456, dtype: object
# City number 458 is, City    oga
# Name: 457, dtype: object
# City number 459 is, City    strathroy
# Name: 458, dtype: object
# City number 460 is, City    bilibino
# Name: 459, dtype: object
# City number 461 is, City    port augusta
# Name: 460, dtype: object
# City number 462 is, City    maneadero
# Name: 461, dtype: object
# City number 463 is, City    palmer
# Name: 462, dtype: object
# City number 464 is, City    saint-leu
# Name: 463, dtype: object
# City number 465 is, City    auki
# Name: 464, dtype: object
# City number 466 is, City    chihuahua
# Name: 465, dtype: object
# City number 467 is, City    lavrentiya
# Name: 466, dtype: object
# City number 468 is, City    kamenskoye
# Name: 467, dtype: object
# City number 469 is, City    erzin
# Name: 468, dtype: object
# City number 470 is, City    curup
# Name: 469, dtype: object
# City number 471 is, City    ndele
# Name: 470, dtype: object
# City number 472 is, City    korem
# Name: 471, dtype: object
# City number 473 is, City    maumere
# Name: 472, dtype: object
# City number 474 is, City    mogadishu
# Name: 473, dtype: object
# City number 475 is, City    tuy hoa
# Name: 474, dtype: object
# City number 476 is, City    cayenne
# Name: 475, dtype: object
# City number 477 is, City    yinchuan
# Name: 476, dtype: object
# City number 478 is, City    todos santos
# Name: 477, dtype: object
# City number 479 is, City    lorengau
# Name: 478, dtype: object
# City number 480 is, City    tabou
# Name: 479, dtype: object
# City number 481 is, City    adrar
# Name: 480, dtype: object
# City number 482 is, City    pokhara
# Name: 481, dtype: object
# City number 483 is, City    ponta do sol
# Name: 482, dtype: object
# City number 484 is, City    tabarqah
# Name: 483, dtype: object
# City number 485 is, City    namatanai
# Name: 484, dtype: object
# City number 486 is, City    basmat
# Name: 485, dtype: object
# City number 487 is, City    tarko-sale
# Name: 486, dtype: object
# City number 488 is, City    kavieng
# Name: 487, dtype: object
# City number 489 is, City    navashino
# Name: 488, dtype: object
# City number 490 is, City    xinmin
# Name: 489, dtype: object
# City number 491 is, City    alice springs
# Name: 490, dtype: object
# City number 492 is, City    camacha
# Name: 491, dtype: object
# City number 493 is, City    lazaro cardenas
# Name: 492, dtype: object
# City number 494 is, City    menongue
# Name: 493, dtype: object
# City number 495 is, City    sandnessjoen
# Name: 494, dtype: object
# City number 496 is, City    surubim
# Name: 495, dtype: object
# City number 497 is, City    yellamanchili
# Name: 496, dtype: object
# City number 498 is, City    guilin
# Name: 497, dtype: object
# City number 499 is, City    maarianhamina
# Name: 498, dtype: object
# City number 500 is, City    ovalle
# Name: 499, dtype: object
# City number 501 is, City    dingle
# Name: 500, dtype: object
# City number 502 is, City    tarakan
# Name: 501, dtype: object
# City number 503 is, City    shagonar
# Name: 502, dtype: object
# City number 504 is, City    dwarka
# Name: 503, dtype: object
# City number 505 is, City    robertsport
# Name: 504, dtype: object
# City number 506 is, City    pathein
# Name: 505, dtype: object
# City number 507 is, City    ulagan
# Name: 506, dtype: object
# City number 508 is, City    rungata
# Name: 507, dtype: object
# City number 509 is, City    anaco
# Name: 508, dtype: object
# City number 510 is, City    la ronge
# Name: 509, dtype: object
# City number 511 is, City    bazarnyye mataki
# Name: 510, dtype: object
# City number 512 is, City    karkaralinsk
# Name: 511, dtype: object
# City number 513 is, City    santo andre
# Name: 512, dtype: object
# City number 514 is, City    chibombo
# Name: 513, dtype: object
# City number 515 is, City    kirando
# Name: 514, dtype: object
# City number 516 is, City    yicheng
# Name: 515, dtype: object
# City number 517 is, City    linfen
# Name: 516, dtype: object
# City number 518 is, City    alausi
# Name: 517, dtype: object
# City number 519 is, City    clyde river
# Name: 518, dtype: object
# City number 520 is, City    arlit
# Name: 519, dtype: object
# City number 521 is, City    mackay
# Name: 520, dtype: object
# City number 522 is, City    fort nelson
# Name: 521, dtype: object
# City number 523 is, City    sindand
# Name: 522, dtype: object
# City number 524 is, City    ushumun
# Name: 523, dtype: object
# City number 525 is, City    tahe
# Name: 524, dtype: object
# City number 526 is, City    sao borja
# Name: 525, dtype: object
# City number 527 is, City    san-pedro
# Name: 526, dtype: object
# City number 528 is, City    houma
# Name: 527, dtype: object
# City number 529 is, City    bedford
# Name: 528, dtype: object
# City number 530 is, City    cuamba
# Name: 529, dtype: object
# City number 531 is, City    kaohsiung
# Name: 530, dtype: object
# City number 532 is, City    luwuk
# Name: 531, dtype: object
# City number 533 is, City    willmar
# Name: 532, dtype: object
# City number 534 is, City    la sarre
# Name: 533, dtype: object
# City number 535 is, City    olafsvik
# Name: 534, dtype: object
# City number 536 is, City    komsomolets
# Name: 535, dtype: object
# City number 537 is, City    westport
# Name: 536, dtype: object
# City number 538 is, City    coquimbo
# Name: 537, dtype: object
# City number 539 is, City    honggang
# Name: 538, dtype: object
# City number 540 is, City    tromso
# Name: 539, dtype: object
# City number 541 is, City    kununurra
# Name: 540, dtype: object
# City number 542 is, City    merauke
# Name: 541, dtype: object
# City number 543 is, City    macae
# Name: 542, dtype: object
# City number 544 is, City    puerto escondido
# Name: 543, dtype: object
# City number 545 is, City    grand-santi
# Name: 544, dtype: object
# City number 546 is, City    luis correia
# Name: 545, dtype: object
# City number 547 is, City    kroya
# Name: 546, dtype: object
# City number 548 is, City    barbar
# Name: 547, dtype: object
# City number 549 is, City    lufilufi
# Name: 548, dtype: object
# City number 550 is, City    molteno
# Name: 549, dtype: object
# City number 551 is, City    gillette
# Name: 550, dtype: object
# City number 552 is, City    viedma
# Name: 551, dtype: object
# City number 553 is, City    talaya
# Name: 552, dtype: object
# City number 554 is, City    conde
# Name: 553, dtype: object
# City number 555 is, City    warqla
# Name: 554, dtype: object
# City number 556 is, City    kirakira
# Name: 555, dtype: object
# City number 557 is, City    bonavista
# Name: 556, dtype: object
# City number 558 is, City    bundaberg
# Name: 557, dtype: object
# City number 559 is, City    casino
# Name: 558, dtype: object
# City number 560 is, City    ivankiv
# Name: 559, dtype: object
# City number 561 is, City    esmeraldas
# Name: 560, dtype: object
# City number 562 is, City    sept-iles
# Name: 561, dtype: object
# City number 563 is, City    huarmey
# Name: 562, dtype: object
# City number 564 is, City    mana
# Name: 563, dtype: object
# City number 565 is, City    arroyo
# Name: 564, dtype: object
# City number 566 is, City    lahaina
# Name: 565, dtype: object
# City number 567 is, City    aklavik
# Name: 566, dtype: object
# City number 568 is, City    narragansett
# Name: 567, dtype: object
# City number 569 is, City    dinguiraye
# Name: 568, dtype: object
# City number 570 is, City    aktash
# Name: 569, dtype: object
# City number 571 is, City    ilulissat
# Name: 570, dtype: object
# City number 572 is, City    lamlash
# Name: 571, dtype: object
# City number 573 is, City    wuning
# Name: 572, dtype: object
# City number 574 is, City    ngama
# Name: 573, dtype: object
# City number 575 is, City    furstenfeld
# Name: 574, dtype: object
# City number 576 is, City    tyumentsevo
# Name: 575, dtype: object
# City number 577 is, City    alta floresta
# Name: 576, dtype: object
# City number 578 is, City    aksarka
# Name: 577, dtype: object
# City number 579 is, City    bignona
# Name: 578, dtype: object
# City number 580 is, City    thunder bay
# Name: 579, dtype: object
# City number 581 is, City    opuwo
# Name: 580, dtype: object
# City number 582 is, City    pombas
# Name: 581, dtype: object
# City number 583 is, City    innisfail
# Name: 582, dtype: object
# City number 584 is, City    ponta delgada
# Name: 583, dtype: object
# City number 585 is, City    okhotsk
# Name: 584, dtype: object
# City number 586 is, City    iquique
# Name: 585, dtype: object
# City number 587 is, City    santa cruz de tenerife
# Name: 586, dtype: object
# City number 588 is, City    tommot
# Name: 587, dtype: object
# City number 589 is, City    boulder city
# Name: 588, dtype: object
# City number 590 is, City    parabel
# Name: 589, dtype: object
# City number 591 is, City    clausthal-zellerfeld
# Name: 590, dtype: object
# City number 592 is, City    makurdi
# Name: 591, dtype: object
# City number 593 is, City    mareeba
# Name: 592, dtype: object
# City number 594 is, City    gawler
# Name: 593, dtype: object
# City number 595 is, City    surt
# Name: 594, dtype: object
# City number 596 is, City    grand river south east
# Name: 595, dtype: object
# City number 597 is, City    ust-kamchatsk
# Name: 596, dtype: object
# City number 598 is, City    thongwa
# Name: 597, dtype: object
# City number 599 is, City    banjar
# Name: 598, dtype: object
# City number 600 is, City    prince rupert
# Name: 599, dtype: object
# City number 601 is, City    beamsville
# Name: 600, dtype: object
# City number 602 is, City    edgewater
# Name: 601, dtype: object
# City number 603 is, City    yanchukan
# Name: 602, dtype: object
# City number 604 is, City    esso
# Name: 603, dtype: object
# City number 605 is, City    port hedland
# Name: 604, dtype: object
# City number 606 is, City    abancay
# Name: 605, dtype: object
# City number 607 is, City    nuuk
# Name: 606, dtype: object
# City number 608 is, City    bolonchen
# Name: 607, dtype: object
# City number 609 is, City    tigil
# Name: 608, dtype: object
# City number 610 is, City    husavik
# Name: 609, dtype: object
# City number 611 is, City    becerril
# Name: 610, dtype: object
# City number 612 is, City    tateyama
# Name: 611, dtype: object
# City number 613 is, City    pedasi
# Name: 612, dtype: object
# City number 614 is, City    vicuna
# Name: 613, dtype: object
# City number 615 is, City    umm lajj
# Name: 614, dtype: object
# City number 616 is, City    camacupa
# Name: 615, dtype: object
# City number 617 is, City    blagoyevo
# Name: 616, dtype: object
# City number 618 is, City    tir pol
# Name: 617, dtype: object
# City number 619 is, City    marsh harbour
# Name: 618, dtype: object
# City number 620 is, City    saint-francois
# Name: 619, dtype: object
# City number 621 is, City    saeby
# Name: 620, dtype: object
# City number 622 is, City    hofn
# Name: 621, dtype: object
# City number 623 is, City    ariogala
# Name: 622, dtype: object
# City number 624 is, City    gornopravdinsk
# Name: 623, dtype: object
# City number 625 is, City    sawakin
# Name: 624, dtype: object
# City number 626 is, City    taltal
# Name: 625, dtype: object
# City number 627 is, City    letlhakane
# Name: 626, dtype: object
# City number 628 is, City    amazar
# Name: 627, dtype: object

# %% [raw]
# pprint(weather_data)

# %%
response = []
for entry in weather_data.json():
    n += 1
    time.sleep(1)
    weather_data.append(owm.get_current(**settings))
    response_json.append(response)
    print(f"City number {n} is, {row}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-e6aa51371a70> in <module>
#       1 response = []
# ----> 2 for entry in weather_data.json():
#       3     n += 1
#       4     time.sleep(1)
#       5     weather_data.append(owm.get_current(**settings))
#
# AttributeError: 'list' object has no attribute 'json'

# %%
pprint(weather_data)
# Out:
# [[{'clouds': {'all': 2},
#    'coord': {'lat': -23.1203, 'lon': -134.9692},
#    'dt': 1569438691,
#    'id': 4030556,
#    'main': {'grnd_level': 1021.48,
#             'humidity': 68,
#             'pressure': 1021.4,
#             'sea_level': 1021.4,
#             'temp': 21.85,
#             'temp_max': 21.85,
#             'temp_min': 21.85},
#    'name': 'Rikitea',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'PF'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 83.752, 'speed': 3.43}}],
#  [{'clouds': {'all': 75},
#    'coord': {'lat': 23.9912, 'lon': -104.675},
#    'dt': 1569438569,
#    'id': 4011743,
#    'main': {'humidity': 43,
#             'pressure': 1024,
#             'temp': 22.19,
#             'temp_max': 23.89,
#             'temp_min': 21},
#    'name': 'Constitucion',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'MX'},
#    'weather': [{'description': 'broken clouds',
#                 'icon': '04d',
#                 'id': 803,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 60, 'speed': 2.1}},
#   {'clouds': {'all': 75},
#    'coord': {'lat': 20.5684, 'lon': -97.651},
#    'dt': 1569438689,
#    'id': 3818580,
#    'main': {'humidity': 59,
#             'pressure': 1012,
#             'temp': 33,
#             'temp_max': 33,
#             'temp_min': 33},
#    'name': 'Constitucion',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'MX'},
#    'weather': [{'description': 'broken clouds',
#                 'icon': '04d',
#                 'id': 803,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 100, 'speed': 3.1}}],
#  [{'clouds': {'all': 75},
#    'coord': {'lat': -54.807, 'lon': -68.3074},
#    'dt': 1569438568,
#    'id': 3833367,
#    'main': {'humidity': 60,
#             'pressure': 1002,
#             'temp': 5,
#             'temp_max': 5,
#             'temp_min': 5},
#    'name': 'Ushuaia',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'AR'},
#    'weather': [{'description': 'drizzle',
#                 'icon': '09d',
#                 'id': 301,
#                 'main': 'Drizzle'}],
#    'wind': {'deg': 230, 'speed': 8.2}}],
#  [{'clouds': {'all': 40},
#    'coord': {'lat': 13.2167, 'lon': -59.5167},
#    'dt': 1569438680,
#    'id': 3374083,
#    'main': {'humidity': 66,
#             'pressure': 1013,
#             'temp': 31,
#             'temp_max': 31,
#             'temp_min': 31},
#    'name': 'Bathsheba',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'BB'},
#    'weather': [{'description': 'scattered clouds',
#                 'icon': '03d',
#                 'id': 802,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 130, 'speed': 4.1}}],
#  [{'clouds': {'all': 21},
#    'coord': {'lat': -34.1009, 'lon': -56.2148},
#    'dt': 1569438566,
#    'id': 3442585,
#    'main': {'grnd_level': 1005.8,
#             'humidity': 57,
#             'pressure': 1019.59,
#             'sea_level': 1019.59,
#             'temp': 22.95,
#             'temp_max': 22.95,
#             'temp_min': 22.95},
#    'name': 'Florida',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'UY'},
#    'weather': [{'description': 'few clouds',
#                 'icon': '02d',
#                 'id': 801,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 256.751, 'speed': 2.74}},
#   {'clouds': {'all': 75},
#    'coord': {'lat': 21.5268, 'lon': -78.2258},
#    'dt': 1569438567,
#    'id': 3558771,
#    'main': {'humidity': 62,
#             'pressure': 1010,
#             'temp': 31,
#             'temp_max': 31,
#             'temp_min': 31},
#    'name': 'Florida',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'CU'},
#    'weather': [{'description': 'broken clouds',
#                 'icon': '04d',
#                 'id': 803,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 20, 'speed': 6.7}},
#   {'clouds': {'all': 1},
#    'coord': {'lat': 18.363, 'lon': -66.567},
#    'dt': 1569438696,
#    'id': 4564991,
#    'main': {'humidity': 74,
#             'pressure': 1012,
#             'temp': 29.01,
#             'temp_max': 32,
#             'temp_min': 26.67},
#    'name': 'Florida',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'PR'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 220, 'speed': 5.7}},
#   {'clouds': {'all': 75},
#    'coord': {'lat': 3.3256, 'lon': -76.2371},
#    'dt': 1569438568,
#    'id': 3682393,
#    'main': {'humidity': 61,
#             'pressure': 1016,
#             'temp': 26,
#             'temp_max': 26,
#             'temp_min': 26},
#    'name': 'Florida',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'CO'},
#    'weather': [{'description': 'haze',
#                 'icon': '50d',
#                 'id': 721,
#                 'main': 'Haze'}],
#    'wind': {'speed': 1}},
#   {'clouds': {'all': 0},
#    'coord': {'lat': -34.5323, 'lon': -58.4938},
#    'dt': 1569438681,
#    'id': 3435910,
#    'main': {'humidity': 20,
#             'pressure': 1017,
#             'temp': 29.48,
#             'temp_max': 31.67,
#             'temp_min': 27},
#    'name': 'Florida',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'AR'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 280, 'speed': 3.6}}],
#  [{'clouds': {'all': 75},
#    'coord': {'lat': 69.444, 'lon': -133.032},
#    'dt': 1569438707,
#    'id': 6170031,
#    'main': {'humidity': 93,
#             'pressure': 1008,
#             'temp': 3,
#             'temp_max': 3,
#             'temp_min': 3},
#    'name': 'Tuktoyaktuk',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'CA'},
#    'weather': [{'description': 'broken clouds',
#                 'icon': '04d',
#                 'id': 803,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 210, 'speed': 2.6}}],
#  [{'clouds': {'all': 20},
#    'coord': {'lat': 51.4542, 'lon': 8.855},
#    'dt': 1569438643,
#    'id': 2873211,
#    'main': {'humidity': 82,
#             'pressure': 1007,
#             'temp': 13.6,
#             'temp_max': 16.11,
#             'temp_min': 11.11},
#    'name': 'Marsberg',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'DE'},
#    'weather': [{'description': 'few clouds',
#                 'icon': '02n',
#                 'id': 801,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 180, 'speed': 3.1}},
#   {'clouds': {'all': 20},
#    'coord': {'lat': 48.3934, 'lon': 12.2592},
#    'dt': 1569438639,
#    'id': 2881485,
#    'main': {'humidity': 82,
#             'pressure': 1012,
#             'temp': 13.03,
#             'temp_max': 13.89,
#             'temp_min': 12.78},
#    'name': 'Marsberg',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'DE'},
#    'weather': [{'description': 'few clouds',
#                 'icon': '02n',
#                 'id': 801,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 260, 'speed': 2.6}}],
#  [{'clouds': {'all': 15},
#    'coord': {'lat': -30.1658, 'lon': -50.2184},
#    'dt': 1569438683,
#    'id': 3466165,
#    'main': {'grnd_level': 1018.04,
#             'humidity': 59,
#             'pressure': 1018.77,
#             'sea_level': 1018.77,
#             'temp': 22.05,
#             'temp_max': 22.05,
#             'temp_min': 22.05},
#    'name': 'Cidreira',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'BR'},
#    'weather': [{'description': 'few clouds',
#                 'icon': '02d',
#                 'id': 801,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 66.523, 'speed': 4.33}}],
#  [{'clouds': {'all': 90},
#    'coord': {'lat': 22.0752, 'lon': -159.319},
#    'dt': 1569438705,
#    'id': 5848280,
#    'main': {'humidity': 83,
#             'pressure': 1014,
#             'temp': 25.79,
#             'temp_max': 27,
#             'temp_min': 25},
#    'name': 'Kapaa',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'overcast clouds',
#                 'icon': '04d',
#                 'id': 804,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 160, 'speed': 4.1}}],
#  [{'clouds': {'all': 17},
#    'coord': {'lat': -23.58, 'lon': 149.0661},
#    'dt': 1569438590,
#    'id': 2175403,
#    'main': {'grnd_level': 1001.35,
#             'humidity': 93,
#             'pressure': 1022.15,
#             'sea_level': 1022.15,
#             'temp': 15.65,
#             'temp_max': 15.65,
#             'temp_min': 15.65},
#    'name': 'Bluff',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'AU'},
#    'weather': [{'description': 'few clouds',
#                 'icon': '02n',
#                 'id': 801,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 73.302, 'speed': 3.94}},
#   {'clouds': {'all': 90},
#    'coord': {'lat': 64.7156, 'lon': -147.1761},
#    'dt': 1569438588,
#    'id': 5879898,
#    'main': {'humidity': 100,
#             'pressure': 1008,
#             'temp': 1.49,
#             'temp_max': 2.78,
#             'temp_min': 0.56},
#    'name': 'Bluff',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'mist',
#                 'icon': '50d',
#                 'id': 701,
#                 'main': 'Mist'}],
#    'wind': {'deg': 70, 'speed': 4.1}},
#   {'clouds': {'all': 1},
#    'coord': {'lat': 33.9398, 'lon': -95.6931},
#    'dt': 1569438583,
#    'id': 4539145,
#    'main': {'humidity': 65,
#             'pressure': 1011,
#             'temp': 30.62,
#             'temp_max': 32.22,
#             'temp_min': 28},
#    'name': 'Bluff',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 180, 'speed': 3.6}},
#   {'clouds': {'all': 75},
#    'coord': {'lat': 34.6134, 'lon': -88.9559},
#    'dt': 1569438582,
#    'id': 4438121,
#    'main': {'humidity': 55,
#             'pressure': 1012,
#             'temp': 32.37,
#             'temp_max': 35.56,
#             'temp_min': 30},
#    'name': 'Bluff',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'broken clouds',
#                 'icon': '04d',
#                 'id': 803,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 290, 'speed': 5.1}},
#   {'clouds': {'all': 1},
#    'coord': {'lat': 33.8207, 'lon': -87.9065},
#    'dt': 1569438692,
#    'id': 4098161,
#    'main': {'humidity': 52,
#             'pressure': 1012,
#             'temp': 33.18,
#             'temp_max': 35,
#             'temp_min': 32},
#    'name': 'Bluff',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'speed': 2.6}}],
#  [{'clouds': {'all': 0},
#    'coord': {'lat': -38.3131, 'lon': -60.2291},
#    'dt': 1569438568,
#    'id': 3833859,
#    'main': {'grnd_level': 1007.81,
#             'humidity': 37,
#             'pressure': 1019.06,
#             'sea_level': 1019.06,
#             'temp': 23.95,
#             'temp_max': 23.95,
#             'temp_min': 23.95},
#    'name': 'Barrow',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'AR'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 209.49, 'speed': 2.71}},
#   {'clouds': {'all': 40},
#    'coord': {'lat': 52.7271, 'lon': -0.6831},
#    'dt': 1569438629,
#    'id': 2642763,
#    'main': {'humidity': 82,
#             'pressure': 1000,
#             'temp': 15.47,
#             'temp_max': 17,
#             'temp_min': 13.89},
#    'name': 'Barrow',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'GB'},
#    'weather': [{'description': 'scattered clouds',
#                 'icon': '03n',
#                 'id': 802,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 220, 'speed': 3.1}},
#   {'clouds': {'all': 40},
#    'coord': {'lat': 52.2422, 'lon': 0.5837},
#    'dt': 1569438630,
#    'id': 2656248,
#    'main': {'humidity': 93,
#             'pressure': 1001,
#             'temp': 15.71,
#             'temp_max': 17,
#             'temp_min': 14.44},
#    'name': 'Barrow',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'GB'},
#    'weather': [{'description': 'scattered clouds',
#                 'icon': '03n',
#                 'id': 802,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 250, 'speed': 3.1}},
#   {'clouds': {'all': 40},
#    'coord': {'lat': 53.8407, 'lon': -2.4026},
#    'dt': 1569438627,
#    'id': 2655524,
#    'main': {'humidity': 93,
#             'pressure': 999,
#             'temp': 14.94,
#             'temp_max': 16.11,
#             'temp_min': 13.89},
#    'name': 'Barrow',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'GB'},
#    'weather': [{'description': 'scattered clouds',
#                 'icon': '03n',
#                 'id': 802,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 160, 'speed': 1.5}},
#   {'clouds': {'all': 40},
#    'coord': {'lat': 51.9226, 'lon': -2.169},
#    'dt': 1569438628,
#    'id': 2648402,
#    'main': {'humidity': 88,
#             'pressure': 1001,
#             'temp': 15.43,
#             'temp_max': 17,
#             'temp_min': 13.89},
#    'name': 'Barrow',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'GB'},
#    'weather': [{'description': 'scattered clouds',
#                 'icon': '03n',
#                 'id': 802,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 220, 'speed': 3.1}}],
#  [{'clouds': {'all': 1},
#    'coord': {'lat': -11.3848, 'lon': 43.2844},
#    'dt': 1569438576,
#    'id': 921786,
#    'main': {'grnd_level': 1015.48,
#             'humidity': 79,
#             'pressure': 1015.58,
#             'sea_level': 1015.58,
#             'temp': 25.95,
#             'temp_max': 25.95,
#             'temp_min': 25.95},
#    'name': 'Mitsamiouli',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'KM'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01n',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 168.491, 'speed': 10.61}}],
#  [{'clouds': {'all': 0},
#    'coord': {'lat': 71.965, 'lon': 114.0939},
#    'dt': 1569438601,
#    'id': 2017155,
#    'main': {'grnd_level': 987.73,
#             'humidity': 89,
#             'pressure': 997.77,
#             'sea_level': 997.77,
#             'temp': -0.55,
#             'temp_max': -0.55,
#             'temp_min': -0.55},
#    'name': 'Saskylakh',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'RU'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01n',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 208.612, 'speed': 3.24}}],
#  [{'clouds': {'all': 75},
#    'coord': {'lat': 67.667, 'lon': 12.6934},
#    'dt': 1569438673,
#    'id': 3137469,
#    'main': {'humidity': 93,
#             'pressure': 1015,
#             'temp': 9.52,
#             'temp_max': 10,
#             'temp_min': 9},
#    'name': 'Sorland',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'NO'},
#    'weather': [{'description': 'light intensity drizzle',
#                 'icon': '09n',
#                 'id': 300,
#                 'main': 'Drizzle'}],
#    'wind': {'deg': 40, 'speed': 1.5}}],
#  [{'clouds': {'all': 0},
#    'coord': {'lat': -34.4176, 'lon': 19.2361},
#    'dt': 1569438566,
#    'id': 3366880,
#    'main': {'humidity': 60,
#             'pressure': 1021,
#             'temp': 17.83,
#             'temp_max': 18.33,
#             'temp_min': 17.22},
#    'name': 'Hermanus',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'ZA'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01n',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 82, 'speed': 0.45}}],
#  [{'clouds': {'all': 84},
#    'coord': {'lat': -46.1928, 'lon': 168.8643},
#    'dt': 1569438580,
#    'id': 6201424,
#    'main': {'humidity': 84,
#             'pressure': 1000,
#             'temp': 6.67,
#             'temp_max': 6.67,
#             'temp_min': 6.67},
#    'name': 'Mataura',
#    'rain': None,
#    'snow': {'3h': 2.188},
#    'sys': {'country': 'NZ'},
#    'weather': [{'description': 'broken clouds',
#                 'icon': '04n',
#                 'id': 803,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 229, 'speed': 7.15}}],
#  [{'clouds': {'all': 46},
#    'coord': {'lat': 22.5702, 'lon': 59.5299},
#    'dt': 1569438544,
#    'id': 286245,
#    'main': {'grnd_level': 993.16,
#             'humidity': 73,
#             'pressure': 1010.82,
#             'sea_level': 1010.82,
#             'temp': 26.75,
#             'temp_max': 26.75,
#             'temp_min': 26.75},
#    'name': 'Sur',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'OM'},
#    'weather': [{'description': 'scattered clouds',
#                 'icon': '03n',
#                 'id': 802,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 182.073, 'speed': 4.23}},
#   {'clouds': {'all': 0},
#    'coord': {'lat': 37.9112, 'lon': 40.2366},
#    'dt': 1569438544,
#    'id': 316541,
#    'main': {'humidity': 25,
#             'pressure': 1013,
#             'temp': 23.93,
#             'temp_max': 24,
#             'temp_min': 23.89},
#    'name': 'Sur',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'TR'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01n',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 260, 'speed': 2.1}},
#   {'clouds': {'all': 0},
#    'coord': {'lat': -31.6626, 'lon': -64.4301},
#    'dt': 1569438568,
#    'id': 3866163,
#    'main': {'humidity': 17,
#             'pressure': 1020,
#             'temp': 29.07,
#             'temp_max': 31.11,
#             'temp_min': 27.22},
#    'name': 'Sur',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'AR'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 90, 'speed': 4.6}},
#   {'clouds': {'all': 89},
#    'coord': {'lat': -46.7972, 'lon': -67.9472},
#    'dt': 1569438689,
#    'id': 3841309,
#    'main': {'grnd_level': 989.96,
#             'humidity': 34,
#             'pressure': 1013.52,
#             'sea_level': 1013.52,
#             'temp': 19.45,
#             'temp_max': 19.45,
#             'temp_min': 19.45},
#    'name': 'Sur',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'AR'},
#    'weather': [{'description': 'overcast clouds',
#                 'icon': '04d',
#                 'id': 804,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 253.307, 'speed': 8.03}},
#   {'clouds': {'all': 88},
#    'coord': {'lat': 46.5211, 'lon': 9.6311},
#    'dt': 1569438632,
#    'id': 2660522,
#    'main': {'humidity': 93,
#             'pressure': 1010,
#             'temp': 11.21,
#             'temp_max': 15,
#             'temp_min': 6.11},
#    'name': 'Sur',
#    'rain': {'3h': 0.375},
#    'snow': None,
#    'sys': {'country': 'CH'},
#    'weather': [{'description': 'light rain',
#                 'icon': '10n',
#                 'id': 500,
#                 'main': 'Rain'}],
#    'wind': {'deg': 12.855, 'speed': 3.94}}],
#  [],
#  [{'clouds': {'all': 75},
#    'coord': {'lat': 65.6145, 'lon': -37.6368},
#    'dt': 1569438681,
#    'id': 3424607,
#    'main': {'humidity': 87,
#             'pressure': 999,
#             'temp': 8,
#             'temp_max': 8,
#             'temp_min': 8},
#    'name': 'Tasiilaq',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'GL'},
#    'weather': [{'description': 'broken clouds',
#                 'icon': '04d',
#                 'id': 803,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 240, 'speed': 2.6}}],
#  [{'clouds': {'all': 84},
#    'coord': {'lat': -2.9248, 'lon': -39.9167},
#    'dt': 1569438680,
#    'id': 3393692,
#    'main': {'grnd_level': 1006.61,
#             'humidity': 51,
#             'pressure': 1010.64,
#             'sea_level': 1010.64,
#             'temp': 30.55,
#             'temp_max': 30.55,
#             'temp_min': 30.55},
#    'name': 'Itarema',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'BR'},
#    'weather': [{'description': 'broken clouds',
#                 'icon': '04d',
#                 'id': 803,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 72.17, 'speed': 7.42}}],
#  [{'clouds': {'all': 90},
#    'coord': {'lat': 64.8378, 'lon': -147.7167},
#    'dt': 1569438572,
#    'id': 5861897,
#    'main': {'humidity': 100,
#             'pressure': 1008,
#             'temp': 1.45,
#             'temp_max': 2.78,
#             'temp_min': 0.56},
#    'name': 'Fairbanks',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'mist',
#                 'icon': '50d',
#                 'id': 701,
#                 'main': 'Mist'}],
#    'wind': {'deg': 70, 'speed': 4.1}},
#   {'clouds': {'all': 40},
#    'coord': {'lat': 39.2195, 'lon': -87.5223},
#    'dt': 1569438693,
#    'id': 4265507,
#    'main': {'humidity': 57,
#             'pressure': 1010,
#             'temp': 26.66,
#             'temp_max': 28,
#             'temp_min': 25},
#    'name': 'Fairbanks',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'scattered clouds',
#                 'icon': '03d',
#                 'id': 802,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 230, 'speed': 5.1}},
#   {'clouds': {'all': 1},
#    'coord': {'lat': 38.8657, 'lon': -120.6703},
#    'dt': 1569438587,
#    'id': 5345659,
#    'main': {'humidity': 28,
#             'pressure': 1012,
#             'temp': 29.85,
#             'temp_max': 33.33,
#             'temp_min': 20},
#    'name': 'Fairbanks',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 340, 'speed': 2.1}},
#   {'clouds': {'all': 1},
#    'coord': {'lat': 45.624, 'lon': -121.0021},
#    'dt': 1569438705,
#    'id': 5756304,
#    'main': {'humidity': 48,
#             'pressure': 1025,
#             'temp': 17.48,
#             'temp_max': 20,
#             'temp_min': 14.44},
#    'name': 'Fairbanks',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 350, 'speed': 2.1}},
#   {'clouds': {'all': 1},
#    'coord': {'lat': 32.6443, 'lon': -92.0366},
#    'dt': 1569438694,
#    'id': 4333669,
#    'main': {'humidity': 38,
#             'pressure': 1014,
#             'temp': 33.71,
#             'temp_max': 35.56,
#             'temp_min': 32},
#    'name': 'Fairbanks',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 220, 'speed': 3.1}}],
#  [{'clouds': {'all': 76},
#    'coord': {'lat': -42.8826, 'lon': 147.3281},
#    'dt': 1569438558,
#    'id': 2163355,
#    'main': {'humidity': 70,
#             'pressure': 1021,
#             'temp': 8.47,
#             'temp_max': 10,
#             'temp_min': 6.11},
#    'name': 'Hobart',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'AU'},
#    'weather': [{'description': 'broken clouds',
#                 'icon': '04n',
#                 'id': 803,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 330, 'speed': 5.1}},
#   {'clouds': {'all': 1},
#    'coord': {'lat': 47.4144, 'lon': -121.9724},
#    'dt': 1569438588,
#    'id': 5797430,
#    'main': {'humidity': 63,
#             'pressure': 1026,
#             'temp': 17.23,
#             'temp_max': 18.89,
#             'temp_min': 15.56},
#    'name': 'Hobart',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 360, 'speed': 2.1}},
#   {'clouds': {'all': 1},
#    'coord': {'lat': 41.5323, 'lon': -87.2551},
#    'dt': 1569438570,
#    'id': 4921476,
#    'main': {'humidity': 69,
#             'pressure': 1008,
#             'temp': 24.35,
#             'temp_max': 26.67,
#             'temp_min': 21.67},
#    'name': 'Hobart',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 250, 'speed': 5.1}},
#   {'clouds': {'all': 1},
#    'coord': {'lat': 35.0295, 'lon': -99.0932},
#    'dt': 1569438695,
#    'id': 4538821,
#    'main': {'humidity': 52,
#             'pressure': 1010,
#             'temp': 32.55,
#             'temp_max': 34.44,
#             'temp_min': 31},
#    'name': 'Hobart',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'haze',
#                 'icon': '50d',
#                 'id': 721,
#                 'main': 'Haze'}],
#    'wind': {'deg': 200, 'speed': 5.7}},
#   {'clouds': {'all': 4},
#    'coord': {'lat': 42.3715, 'lon': -74.6705},
#    'dt': 1569438701,
#    'id': 5139428,
#    'main': {'humidity': 54,
#             'pressure': 1010,
#             'temp': 22.23,
#             'temp_max': 23.89,
#             'temp_min': 20.56},
#    'name': 'Hobart',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 307, 'speed': 0.45}}],
#  [{'clouds': {'all': 97},
#    'coord': {'lat': 50.6789, 'lon': 156.125},
#    'dt': 1569438605,
#    'id': 2121385,
#    'main': {'grnd_level': 982.69,
#             'humidity': 87,
#             'pressure': 983.23,
#             'sea_level': 983.23,
#             'temp': 9.15,
#             'temp_max': 9.15,
#             'temp_min': 9.15},
#    'name': 'Severo-Kurilsk',
#    'rain': {'3h': 6},
#    'snow': None,
#    'sys': {'country': 'RU'},
#    'weather': [{'description': 'moderate rain',
#                 'icon': '10n',
#                 'id': 501,
#                 'main': 'Rain'}],
#    'wind': {'deg': 227.481, 'speed': 8.76}}],
#  [{'clouds': {'all': 0},
#    'coord': {'lat': -3.7125, 'lon': -38.6045},
#    'dt': 1569438566,
#    'id': 6320062,
#    'main': {'humidity': 62,
#             'pressure': 1011,
#             'temp': 27.34,
#             'temp_max': 29,
#             'temp_min': 26.11},
#    'name': 'Vila Velha',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'BR'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 80, 'speed': 7.7}},
#   {'clouds': {'all': 73},
#    'coord': {'lat': -11.3335, 'lon': -38.1278},
#    'dt': 1569438682,
#    'id': 3460707,
#    'main': {'grnd_level': 984.15,
#             'humidity': 53,
#             'pressure': 1014.34,
#             'sea_level': 1014.34,
#             'temp': 28.15,
#             'temp_max': 28.15,
#             'temp_min': 28.15},
#    'name': 'Vila Velha',
#    'rain': {'3h': 0.563},
#    'snow': None,
#    'sys': {'country': 'BR'},
#    'weather': [{'description': 'light rain',
#                 'icon': '10d',
#                 'id': 500,
#                 'main': 'Rain'}],
#    'wind': {'deg': 110.214, 'speed': 6.56}},
#   {'clouds': {'all': 40},
#    'coord': {'lat': -7.8086, 'lon': -34.8586},
#    'dt': 1569438566,
#    'id': 3392740,
#    'main': {'humidity': 61,
#             'pressure': 1014,
#             'temp': 28,
#             'temp_max': 28,
#             'temp_min': 28},
#    'name': 'Vila Velha',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'BR'},
#    'weather': [{'description': 'scattered clouds',
#                 'icon': '03d',
#                 'id': 802,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 150, 'speed': 6.2}}],
#  [],
#  [{'clouds': {'all': 1},
#    'coord': {'lat': -26.7853, 'lon': -60.4388},
#    'dt': 1569438568,
#    'id': 3840300,
#    'main': {'grnd_level': 1006.58,
#             'humidity': 21,
#             'pressure': 1018.09,
#             'sea_level': 1018.09,
#             'temp': 30.75,
#             'temp_max': 30.75,
#             'temp_min': 30.75},
#    'name': 'Presidencia Roque Saenz Pena',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'AR'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 152.835, 'speed': 3.72}}],
#  [{'clouds': {'all': 1},
#    'coord': {'lat': 19.7072, 'lon': -155.0817},
#    'dt': 1569438572,
#    'id': 5855927,
#    'main': {'humidity': 57,
#             'pressure': 1015,
#             'temp': 24.64,
#             'temp_max': 27.22,
#             'temp_min': 17.22},
#    'name': 'Hilo',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 5.162, 'speed': 0.97}},
#   {'clouds': {'all': 0},
#    'coord': {'lat': 4.1592, 'lon': 45.4837},
#    'dt': 1569438544,
#    'id': 57060,
#    'main': {'grnd_level': 990.41,
#             'humidity': 69,
#             'pressure': 1010.45,
#             'sea_level': 1010.45,
#             'temp': 26.45,
#             'temp_max': 26.45,
#             'temp_min': 26.45},
#    'name': 'Hilo',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'SO'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01n',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 175.722, 'speed': 10.42}}],
#  [],
#  [],
#  [{'clouds': {'all': 81},
#    'coord': {'lat': -46.2818, 'lon': 169.8464},
#    'dt': 1569438615,
#    'id': 2208248,
#    'main': {'grnd_level': 977.38,
#             'humidity': 88,
#             'pressure': 996.84,
#             'sea_level': 996.84,
#             'temp': 2.75,
#             'temp_max': 2.75,
#             'temp_min': 2.75},
#    'name': 'Kaitangata',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'NZ'},
#    'weather': [{'description': 'broken clouds',
#                 'icon': '04n',
#                 'id': 803,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 250.548, 'speed': 8.34}}],
#  [{'clouds': {'all': 40},
#    'coord': {'lat': -20.6667, 'lon': -40.4976},
#    'dt': 1569438567,
#    'id': 3461888,
#    'main': {'humidity': 69,
#             'pressure': 1019,
#             'temp': 23.45,
#             'temp_max': 24,
#             'temp_min': 22.78},
#    'name': 'Guarapari',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'BR'},
#    'weather': [{'description': 'scattered clouds',
#                 'icon': '03d',
#                 'id': 802,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 80, 'speed': 5.7}}],
#  [{'clouds': {'all': 1},
#    'coord': {'lat': 40.5974, 'lon': -124.1561},
#    'dt': 1569438587,
#    'id': 5563839,
#    'main': {'humidity': 60,
#             'pressure': 1015,
#             'temp': 22.18,
#             'temp_max': 26.11,
#             'temp_min': 20},
#    'name': 'Fortuna',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 280, 'speed': 4.6}},
#   {'clouds': {'all': 4},
#    'coord': {'lat': -5.7332, 'lon': -44.1543},
#    'dt': 1569438680,
#    'id': 3399377,
#    'main': {'grnd_level': 979.56,
#             'humidity': 17,
#             'pressure': 1008.15,
#             'sea_level': 1008.15,
#             'temp': 39.15,
#             'temp_max': 39.15,
#             'temp_min': 39.15},
#    'name': 'Fortuna',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'BR'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 133.055, 'speed': 2.5}},
#   {'clouds': {'all': 0},
#    'coord': {'lat': 38.1801, 'lon': -1.126},
#    'dt': 1569438623,
#    'id': 2517679,
#    'main': {'humidity': 83,
#             'pressure': 1016,
#             'temp': 23.64,
#             'temp_max': 25,
#             'temp_min': 22.22},
#    'name': 'Fortuna',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'ES'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01n',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 70, 'speed': 3.1}},
#   {'clouds': {'all': 40},
#    'coord': {'lat': -1.8287, 'lon': -79.447},
#    'dt': 1569438568,
#    'id': 3660418,
#    'main': {'humidity': 58,
#             'pressure': 1012,
#             'temp': 28.95,
#             'temp_max': 29.44,
#             'temp_min': 28.33},
#    'name': 'Fortuna',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'EC'},
#    'weather': [{'description': 'scattered clouds',
#                 'icon': '03d',
#                 'id': 802,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 150, 'speed': 3.6}},
#   {'clouds': {'all': 89},
#    'coord': {'lat': 13.0229, 'lon': 121.3376},
#    'dt': 1569438592,
#    'id': 1693620,
#    'main': {'humidity': 90,
#             'pressure': 1011,
#             'temp': 23.33,
#             'temp_max': 23.33,
#             'temp_min': 23.33},
#    'name': 'Fortuna',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'PH'},
#    'weather': [{'description': 'overcast clouds',
#                 'icon': '04n',
#                 'id': 804,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 73.446, 'speed': 2.68}}],
#  [{'clouds': {'all': 0},
#    'coord': {'lat': 34.5594, 'lon': 76.1256},
#    'dt': 1569438581,
#    'id': 1267776,
#    'main': {'grnd_level': 643.99,
#             'humidity': 56,
#             'pressure': 1023.09,
#             'sea_level': 1023.09,
#             'temp': 11.25,
#             'temp_max': 11.25,
#             'temp_min': 11.25},
#    'name': 'Kargil',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'PK'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01n',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 243.919, 'speed': 4.18}}],
#  [{'clouds': {'all': 53},
#    'coord': {'lat': 54.4423, 'lon': 83.4861},
#    'dt': 1569438584,
#    'id': 1500468,
#    'main': {'grnd_level': 992.82,
#             'humidity': 58,
#             'pressure': 1018.1,
#             'sea_level': 1018.1,
#             'temp': 3.85,
#             'temp_max': 3.85,
#             'temp_min': 3.85},
#    'name': 'Listvyanskiy',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'RU'},
#    'weather': [{'description': 'broken clouds',
#                 'icon': '04n',
#                 'id': 803,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 222.958, 'speed': 3.06}}],
#  [{'clouds': {'all': 75},
#    'coord': {'lat': 63.9359, 'lon': -21.0027},
#    'dt': 1569438681,
#    'id': 3413604,
#    'main': {'humidity': 76,
#             'pressure': 993,
#             'temp': 11.96,
#             'temp_max': 13,
#             'temp_min': 11},
#    'name': 'Selfoss',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'IS'},
#    'weather': [{'description': 'broken clouds',
#                 'icon': '04d',
#                 'id': 803,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 54.669, 'speed': 5.28}}],
#  [{'clouds': {'all': 90},
#    'coord': {'lat': -37.8302, 'lon': 140.7843},
#    'dt': 1569438737,
#    'id': 2156643,
#    'main': {'humidity': 100,
#             'pressure': 1025,
#             'temp': 6,
#             'temp_max': 6,
#             'temp_min': 6},
#    'name': 'Mount Gambier',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'AU'},
#    'weather': [{'description': 'light rain',
#                 'icon': '10n',
#                 'id': 500,
#                 'main': 'Rain'}],
#    'wind': {'deg': 50, 'speed': 3.6}}],
#  [{'clouds': {'all': 7},
#    'coord': {'lat': 20.5183, 'lon': -13.0544},
#    'dt': 1569438618,
#    'id': 2381334,
#    'main': {'grnd_level': 990.53,
#             'humidity': 8,
#             'pressure': 1007.91,
#             'sea_level': 1007.91,
#             'temp': 41.65,
#             'temp_max': 41.65,
#             'temp_min': 41.65},
#    'name': 'Atar',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'MR'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01n',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 16.069, 'speed': 5.91}},
#   {'clouds': {'all': 94},
#    'coord': {'lat': -0.5221, 'lon': 100.7371},
#    'dt': 1569438731,
#    'id': 1625439,
#    'main': {'grnd_level': 924.85,
#             'humidity': 93,
#             'pressure': 1012.45,
#             'sea_level': 1012.45,
#             'temp': 19.35,
#             'temp_max': 19.35,
#             'temp_min': 19.35},
#    'name': 'Atar',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'ID'},
#    'weather': [{'description': 'overcast clouds',
#                 'icon': '04n',
#                 'id': 804,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 71.86, 'speed': 0.49}},
#   {'clouds': {'all': 43},
#    'coord': {'lat': 7.4333, 'lon': 8.6},
#    'dt': 1569438558,
#    'id': 2347266,
#    'main': {'grnd_level': 994.53,
#             'humidity': 84,
#             'pressure': 1010.97,
#             'sea_level': 1010.97,
#             'temp': 26.05,
#             'temp_max': 26.05,
#             'temp_min': 26.05},
#    'name': 'Atar',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'NG'},
#    'weather': [{'description': 'scattered clouds',
#                 'icon': '03n',
#                 'id': 802,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 194.606, 'speed': 2.07}},
#   {'clouds': {'all': 100},
#    'coord': {'lat': 2.4624, 'lon': 31.4376},
#    'dt': 1569438550,
#    'id': 443360,
#    'main': {'grnd_level': 871.73,
#             'humidity': 89,
#             'pressure': 1011.05,
#             'sea_level': 1011.05,
#             'temp': 18.75,
#             'temp_max': 18.75,
#             'temp_min': 18.75},
#    'name': 'Atar',
#    'rain': {'3h': 4.25},
#    'snow': None,
#    'sys': {'country': 'UG'},
#    'weather': [{'description': 'moderate rain',
#                 'icon': '10n',
#                 'id': 501,
#                 'main': 'Rain'}],
#    'wind': {'deg': 238.857, 'speed': 2.53}}],
#  [],
#  [{'clouds': {'all': 0},
#    'coord': {'lat': 43.5562, 'lon': 6.9715},
#    'dt': 1569438728,
#    'id': 3037456,
#    'main': {'humidity': 38,
#             'pressure': 1007,
#             'temp': 21.75,
#             'temp_max': 24,
#             'temp_min': 18.89},
#    'name': 'Saint-Joseph',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'FR'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01n',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 280, 'speed': 5.7}},
#   {'clouds': {'all': 0},
#    'coord': {'lat': 43.3501, 'lon': 5.3832},
#    'dt': 1569438731,
#    'id': 2995468,
#    'main': {'humidity': 64,
#             'pressure': 1013,
#             'temp': 20.49,
#             'temp_max': 22.22,
#             'temp_min': 17.78},
#    'name': 'Saint-Joseph',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'FR'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01n',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 310, 'speed': 4.6}},
#   {'clouds': {'all': 90},
#    'coord': {'lat': 45.5559, 'lon': 4.6179},
#    'dt': 1569438656,
#    'id': 6454140,
#    'main': {'humidity': 82,
#             'pressure': 1014,
#             'temp': 16.04,
#             'temp_max': 17,
#             'temp_min': 14.44},
#    'name': 'Saint-Joseph',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'FR'},
#    'weather': [{'description': 'light rain',
#                 'icon': '10n',
#                 'id': 500,
#                 'main': 'Rain'}],
#    'wind': {'deg': 180, 'speed': 3.1}},
#   {'clouds': {'all': 90},
#    'coord': {'lat': 49.5345, 'lon': -1.5299},
#    'dt': 1569438663,
#    'id': 6614508,
#    'main': {'humidity': 93,
#             'pressure': 1006,
#             'temp': 15.86,
#             'temp_max': 16.67,
#             'temp_min': 15},
#    'name': 'Saint-Joseph',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'FR'},
#    'weather': [{'description': 'shower rain',
#                 'icon': '09n',
#                 'id': 521,
#                 'main': 'Rain'}],
#    'wind': {'deg': 260, 'speed': 6.2}},
#   {'clouds': {'all': 20},
#    'coord': {'lat': 6.1536, 'lon': 1.2331},
#    'dt': 1569438618,
#    'id': 2365267,
#    'main': {'humidity': 83,
#             'pressure': 1012,
#             'temp': 27,
#             'temp_max': 27,
#             'temp_min': 27},
#    'name': 'Saint-Joseph',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'TG'},
#    'weather': [{'description': 'few clouds',
#                 'icon': '02n',
#                 'id': 801,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 210, 'speed': 5.7}}],
#  [{'clouds': {'all': 75},
#    'coord': {'lat': -22.9663, 'lon': -42.0245},
#    'dt': 1569438567,
#    'id': 3471451,
#    'main': {'humidity': 78,
#             'pressure': 1018,
#             'temp': 22,
#             'temp_max': 22,
#             'temp_min': 22},
#    'name': 'Arraial do Cabo',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'BR'},
#    'weather': [{'description': 'broken clouds',
#                 'icon': '04d',
#                 'id': 803,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 60, 'speed': 8.2}}],
#  [{'clouds': {'all': 36},
#    'coord': {'lat': -20.7371, 'lon': 116.8479},
#    'dt': 1569438728,
#    'id': 6620339,
#    'main': {'grnd_level': 1005.43,
#             'humidity': 51,
#             'pressure': 1016.18,
#             'sea_level': 1016.18,
#             'temp': 18.55,
#             'temp_max': 18.55,
#             'temp_min': 18.55},
#    'name': 'Karratha',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'AU'},
#    'weather': [{'description': 'scattered clouds',
#                 'icon': '03n',
#                 'id': 802,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 206.154, 'speed': 4.43}}],
#  [{'clouds': {'all': 87},
#    'coord': {'lat': 6.6231, 'lon': -1.2149},
#    'dt': 1569438558,
#    'id': 2299349,
#    'main': {'grnd_level': 982.05,
#             'humidity': 82,
#             'pressure': 1011.27,
#             'sea_level': 1011.27,
#             'temp': 25.95,
#             'temp_max': 25.95,
#             'temp_min': 25.95},
#    'name': 'Konongo',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'GH'},
#    'weather': [{'description': 'overcast clouds',
#                 'icon': '04n',
#                 'id': 804,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 197.4, 'speed': 1.72}}],
#  [{'clouds': {'all': 75},
#    'coord': {'lat': 6.8026, 'lon': -58.1629},
#    'dt': 1569438566,
#    'id': 3378644,
#    'main': {'humidity': 70,
#             'pressure': 1012,
#             'temp': 32.64,
#             'temp_max': 34,
#             'temp_min': 31},
#    'name': 'Georgetown',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'GY'},
#    'weather': [{'description': 'broken clouds',
#                 'icon': '04d',
#                 'id': 803,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 30, 'speed': 6.2}},
#   {'clouds': {'all': 1},
#    'coord': {'lat': 38.2098, 'lon': -84.5589},
#    'dt': 1569438569,
#    'id': 4292686,
#    'main': {'humidity': 23,
#             'pressure': 1011,
#             'temp': 29.71,
#             'temp_max': 31,
#             'temp_min': 27.78},
#    'name': 'Georgetown',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 230, 'speed': 4.6}},
#   {'clouds': {'all': 0},
#    'coord': {'lat': -33.3609, 'lon': 138.3923},
#    'dt': 1569438737,
#    'id': 2073422,
#    'main': {'grnd_level': 1019.05,
#             'humidity': 59,
#             'pressure': 1024.35,
#             'sea_level': 1024.35,
#             'temp': 10.65,
#             'temp_max': 10.65,
#             'temp_min': 10.65},
#    'name': 'Georgetown',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'AU'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01n',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 74.286, 'speed': 3.85}},
#   {'clouds': {'all': 1},
#    'coord': {'lat': 30.6327, 'lon': -97.6773},
#    'dt': 1569438570,
#    'id': 4693342,
#    'main': {'humidity': 46,
#             'pressure': 1012,
#             'temp': 33.75,
#             'temp_max': 35,
#             'temp_min': 32.22},
#    'name': 'Georgetown',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 160, 'speed': 2.6}},
#   {'clouds': {'all': 75},
#    'coord': {'lat': 46.1844, 'lon': -62.5316},
#    'dt': 1569438706,
#    'id': 5960531,
#    'main': {'humidity': 100,
#             'pressure': 1003,
#             'temp': 15.56,
#             'temp_max': 17.78,
#             'temp_min': 15},
#    'name': 'Georgetown',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'CA'},
#    'weather': [{'description': 'light intensity shower rain',
#                 'icon': '09d',
#                 'id': 520,
#                 'main': 'Rain'}],
#    'wind': {'deg': 330, 'speed': 4.6}}],
#  [],
#  [{'clouds': {'all': 40},
#    'coord': {'lat': 2.8213, 'lon': -60.6724},
#    'dt': 1569438568,
#    'id': 3664980,
#    'main': {'humidity': 49,
#             'pressure': 1010,
#             'temp': 33,
#             'temp_max': 33,
#             'temp_min': 33},
#    'name': 'Boa Vista',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'BR'},
#    'weather': [{'description': 'scattered clouds',
#                 'icon': '03d',
#                 'id': 802,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 70, 'speed': 2.1}},
#   {'clouds': {'all': 57},
#    'coord': {'lat': -0.8215, 'lon': -47.02},
#    'dt': 1569438680,
#    'id': 3388626,
#    'main': {'grnd_level': 1007.35,
#             'humidity': 82,
#             'pressure': 1010.75,
#             'sea_level': 1010.75,
#             'temp': 29.35,
#             'temp_max': 29.35,
#             'temp_min': 29.35},
#    'name': 'Boa Vista',
#    'rain': {'3h': 4.937},
#    'snow': None,
#    'sys': {'country': 'BR'},
#    'weather': [{'description': 'moderate rain',
#                 'icon': '10d',
#                 'id': 501,
#                 'main': 'Rain'}],
#    'wind': {'deg': 43.228, 'speed': 1.28}},
#   {'clouds': {'all': 0},
#    'coord': {'lat': -30.0248, 'lon': -51.1746},
#    'dt': 1569438683,
#    'id': 3452925,
#    'main': {'humidity': 47,
#             'pressure': 1018,
#             'temp': 24.72,
#             'temp_max': 25.56,
#             'temp_min': 23.89},
#    'name': 'Boa Vista',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'BR'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 250, 'speed': 2.6}},
#   {'clouds': {'all': 0},
#    'coord': {'lat': -28.6855, 'lon': -49.4088},
#    'dt': 1569438567,
#    'id': 3465196,
#    'main': {'grnd_level': 1016.87,
#             'humidity': 67,
#             'pressure': 1018.57,
#             'sea_level': 1018.57,
#             'temp': 21.85,
#             'temp_max': 21.85,
#             'temp_min': 21.85},
#    'name': 'Boa Vista',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'BR'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 80.5, 'speed': 5.23}},
#   {'clouds': {'all': 85},
#    'coord': {'lat': -3.3621, 'lon': -39.2088},
#    'dt': 1569438566,
#    'id': 3386177,
#    'main': {'humidity': 84,
#             'pressure': 1010,
#             'temp': 26.11,
#             'temp_max': 26.11,
#             'temp_min': 26.11},
#    'name': 'Boa Vista',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'BR'},
#    'weather': [{'description': 'overcast clouds',
#                 'icon': '04d',
#                 'id': 804,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 136, 'speed': 8.94}}],
#  [{'clouds': {'all': 91},
#    'coord': {'lat': 20.4197, 'lon': 104.0439},
#    'dt': 1569438554,
#    'id': 1652203,
#    'main': {'grnd_level': 896.82,
#             'humidity': 94,
#             'pressure': 1019.76,
#             'sea_level': 1019.76,
#             'temp': 14.75,
#             'temp_max': 14.75,
#             'temp_min': 14.75},
#    'name': 'Xam Nua',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'LA'},
# ...
#                 'icon': '03d',
#                 'id': 802,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 230, 'speed': 5.1}}],
#  [{'clouds': {'all': 40},
#    'coord': {'lat': 28.9889, 'lon': -80.9023},
#    'dt': 1569438569,
#    'id': 4154205,
#    'main': {'humidity': 43,
#             'pressure': 1013,
#             'temp': 32.24,
#             'temp_max': 34.44,
#             'temp_min': 30},
#    'name': 'Edgewater',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'scattered clouds',
#                 'icon': '03d',
#                 'id': 802,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 310, 'speed': 1.5}},
#   {'clouds': {'all': 1},
#    'coord': {'lat': 40.827, 'lon': -73.9757},
#    'dt': 1569438585,
#    'id': 5097575,
#    'main': {'humidity': 36,
#             'pressure': 1011,
#             'temp': 25.05,
#             'temp_max': 26.67,
#             'temp_min': 23.33},
#    'name': 'Edgewater',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 320, 'speed': 2.1}},
#   {'clouds': {'all': 1},
#    'coord': {'lat': 38.9347, 'lon': -76.5533},
#    'dt': 1569438582,
#    'id': 4354072,
#    'main': {'humidity': 36,
#             'pressure': 1012,
#             'temp': 26.85,
#             'temp_max': 28.33,
#             'temp_min': 25},
#    'name': 'Edgewater',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 140, 'speed': 4.6}},
#   {'clouds': {'all': 34},
#    'coord': {'lat': 50.6993, 'lon': -116.1339},
#    'dt': 1569438707,
#    'id': 6115713,
#    'main': {'humidity': 49,
#             'pressure': 1018,
#             'temp': 13.33,
#             'temp_max': 13.33,
#             'temp_min': 13.33},
#    'name': 'Edgewater',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'CA'},
#    'weather': [{'description': 'scattered clouds',
#                 'icon': '03d',
#                 'id': 802,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 357.618, 'speed': 0.55}},
#   {'clouds': {'all': 1},
#    'coord': {'lat': 38.7532, 'lon': -75.205},
#    'dt': 1569438581,
#    'id': 4142643,
#    'main': {'humidity': 31,
#             'pressure': 1012,
#             'temp': 25.82,
#             'temp_max': 28.33,
#             'temp_min': 23.33},
#    'name': 'Edgewater',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'US'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 295.703, 'speed': 2.29}}],
#  [],
#  [{'clouds': {'all': 100},
#    'coord': {'lat': 55.9282, 'lon': 158.7044},
#    'dt': 1569438605,
#    'id': 2125711,
#    'main': {'grnd_level': 866.31,
#             'humidity': 97,
#             'pressure': 981.18,
#             'sea_level': 981.18,
#             'temp': -0.35,
#             'temp_max': -0.35,
#             'temp_min': -0.35},
#    'name': 'Esso',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'RU'},
#    'weather': [{'description': 'overcast clouds',
#                 'icon': '04n',
#                 'id': 804,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 274.045, 'speed': 9.26}}],
#  [{'clouds': {'all': 22},
#    'coord': {'lat': -20.3112, 'lon': 118.5801},
#    'dt': 1569438603,
#    'id': 2063042,
#    'main': {'humidity': 88,
#             'pressure': 1015,
#             'temp': 17,
#             'temp_max': 17,
#             'temp_min': 17},
#    'name': 'Port Hedland',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'AU'},
#    'weather': [{'description': 'few clouds',
#                 'icon': '02n',
#                 'id': 801,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 200, 'speed': 3.1}}],
#  [{'clouds': {'all': 75},
#    'coord': {'lat': -13.6374, 'lon': -72.8789},
#    'dt': 1569438447,
#    'id': 3948642,
#    'main': {'humidity': 55,
#             'pressure': 1041,
#             'temp': 17,
#             'temp_max': 17,
#             'temp_min': 17},
#    'name': 'Abancay',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'PE'},
#    'weather': [{'description': 'broken clouds',
#                 'icon': '04d',
#                 'id': 803,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 30, 'speed': 2.6}}],
#  [{'clouds': {'all': 5},
#    'coord': {'lat': 64.175, 'lon': -51.7356},
#    'dt': 1569438447,
#    'id': 3421319,
#    'main': {'humidity': 56,
#             'pressure': 1009,
#             'temp': 6.85,
#             'temp_max': 7,
#             'temp_min': 6.67},
#    'name': 'Nuuk',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'GL'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01d',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 60, 'speed': 5.7}}],
#  [],
#  [{'clouds': {'all': 100},
#    'coord': {'lat': 57.8, 'lon': 158.6667},
#    'dt': 1569438605,
#    'id': 2120612,
#    'main': {'grnd_level': 971.83,
#             'humidity': 84,
#             'pressure': 979.85,
#             'sea_level': 979.85,
#             'temp': 6.95,
#             'temp_max': 6.95,
#             'temp_min': 6.95},
#    'name': 'Tigil',
#    'rain': {'3h': 1},
#    'snow': None,
#    'sys': {'country': 'RU'},
#    'weather': [{'description': 'light rain',
#                 'icon': '10n',
#                 'id': 500,
#                 'main': 'Rain'}],
#    'wind': {'deg': 22.168, 'speed': 14.75}}],
#  [{'clouds': {'all': 97},
#    'coord': {'lat': 50.5623, 'lon': -96.9949},
#    'dt': 1569438706,
#    'id': 5961417,
#    'main': {'humidity': 71,
#             'pressure': 1006,
#             'temp': 10.83,
#             'temp_max': 11.11,
#             'temp_min': 10.56},
#    'name': 'Husavik',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'CA'},
#    'weather': [{'description': 'overcast clouds',
#                 'icon': '04d',
#                 'id': 804,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 322, 'speed': 3.13}}],
#  [{'clouds': {'all': 35},
#    'coord': {'lat': 9.7033, 'lon': -73.2787},
#    'dt': 1569438688,
#    'id': 3689026,
#    'main': {'grnd_level': 1000.01,
#             'humidity': 58,
#             'pressure': 1010.09,
#             'sea_level': 1010.09,
#             'temp': 33.25,
#             'temp_max': 33.25,
#             'temp_min': 33.25},
#    'name': 'Becerril',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'CO'},
#    'weather': [{'description': 'scattered clouds',
#                 'icon': '03d',
#                 'id': 802,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 262.19, 'speed': 0.86}},
#   {'clouds': {'all': 81},
#    'coord': {'lat': 41.2894, 'lon': -3.3644},
#    'dt': 1569438712,
#    'id': 3111867,
#    'main': {'humidity': 56,
#             'pressure': 1020,
#             'temp': 16.67,
#             'temp_max': 16.67,
#             'temp_min': 16.67},
#    'name': 'Becerril',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'ES'},
#    'weather': [{'description': 'broken clouds',
#                 'icon': '04n',
#                 'id': 803,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 331, 'speed': 0.45}}],
#  [{'clouds': {'all': 92},
#    'coord': {'lat': 36.6634, 'lon': 137.3139},
#    'dt': 1569438599,
#    'id': 1849876,
#    'main': {'humidity': 94,
#             'pressure': 1025,
#             'temp': 15.26,
#             'temp_max': 16.11,
#             'temp_min': 13.89},
#    'name': 'Tateyama',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'JP'},
#    'weather': [{'description': 'overcast clouds',
#                 'icon': '04n',
#                 'id': 804,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 60.736, 'speed': 3.5}}],
#  [{'clouds': {'all': 76},
#    'coord': {'lat': 7.5333, 'lon': -80.0334},
#    'dt': 1569438688,
#    'id': 3703239,
#    'main': {'grnd_level': 980.52,
#             'humidity': 72,
#             'pressure': 1011.08,
#             'sea_level': 1011.08,
#             'temp': 28.25,
#             'temp_max': 28.25,
#             'temp_min': 28.25},
#    'name': 'Pedasi',
#    'rain': {'3h': 9.813},
#    'snow': None,
#    'sys': {'country': 'PA'},
#    'weather': [{'description': 'moderate rain',
#                 'icon': '10d',
#                 'id': 501,
#                 'main': 'Rain'}],
#    'wind': {'deg': 169.024, 'speed': 0.4}}],
#  [],
#  [{'clouds': {'all': 0},
#    'coord': {'lat': 25.024, 'lon': 37.2669},
#    'dt': 1569438543,
#    'id': 100926,
#    'main': {'grnd_level': 1007.67,
#             'humidity': 69,
#             'pressure': 1008.05,
#             'sea_level': 1008.05,
#             'temp': 29.35,
#             'temp_max': 29.35,
#             'temp_min': 29.35},
#    'name': 'Umm Lajj',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'SA'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01n',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 349.035, 'speed': 5.8}}],
#  [{'clouds': {'all': 45},
#    'coord': {'lat': -12.0204, 'lon': 17.4764},
#    'dt': 1569438566,
#    'id': 3351014,
#    'main': {'grnd_level': 832.9,
#             'humidity': 25,
#             'pressure': 1010.54,
#             'sea_level': 1010.54,
#             'temp': 20.95,
#             'temp_max': 20.95,
#             'temp_min': 20.95},
#    'name': 'Camacupa',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'AO'},
#    'weather': [{'description': 'scattered clouds',
#                 'icon': '03n',
#                 'id': 802,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 109.334, 'speed': 1.29}}],
#  [{'clouds': {'all': 99},
#    'coord': {'lat': 63.3667, 'lon': 47.9167},
#    'dt': 1569438559,
#    'id': 576093,
#    'main': {'grnd_level': 987.37,
#             'humidity': 92,
#             'pressure': 1004.49,
#             'sea_level': 1004.49,
#             'temp': 2.65,
#             'temp_max': 2.65,
#             'temp_min': 2.65},
#    'name': 'Blagoyevo',
#    'rain': {'3h': 0.375},
#    'snow': None,
#    'sys': {'country': 'RU'},
#    'weather': [{'description': 'light rain',
#                 'icon': '10n',
#                 'id': 500,
#                 'main': 'Rain'}],
#    'wind': {'deg': 273.722, 'speed': 4.05}}],
#  [],
#  [{'clouds': {'all': 58},
#    'coord': {'lat': 26.5383, 'lon': -77.0611},
#    'dt': 1569438684,
#    'id': 3571913,
#    'main': {'grnd_level': 1012.92,
#             'humidity': 65,
#             'pressure': 1012.99,
#             'sea_level': 1012.99,
#             'temp': 26.45,
#             'temp_max': 26.45,
#             'temp_min': 26.45},
#    'name': 'Marsh Harbour',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'BS'},
#    'weather': [{'description': 'broken clouds',
#                 'icon': '04d',
#                 'id': 803,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 4.665, 'speed': 4.76}}],
#  [{'clouds': {'all': 94},
#    'coord': {'lat': 46.4154, 'lon': 3.9054},
#    'dt': 1569438656,
#    'id': 2980080,
#    'main': {'humidity': 93,
#             'pressure': 1013,
#             'temp': 14.66,
#             'temp_max': 15,
#             'temp_min': 14.44},
#    'name': 'Saint-Francois',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'FR'},
#    'weather': [{'description': 'light rain',
#                 'icon': '10n',
#                 'id': 500,
#                 'main': 'Rain'}],
#    'wind': {'deg': 150, 'speed': 1.5}}],
#  [{'clouds': {'all': 100},
#    'coord': {'lat': 57.3319, 'lon': 10.5225},
#    'dt': 1569438575,
#    'id': 2614172,
#    'main': {'humidity': 96,
#             'pressure': 1008,
#             'temp': 12.78,
#             'temp_max': 12.78,
#             'temp_min': 12.78},
#    'name': 'Saeby',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'DK'},
#    'weather': [{'description': 'overcast clouds',
#                 'icon': '04n',
#                 'id': 804,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 72, 'speed': 0.89}}],
#  [{'clouds': {'all': 90},
#    'coord': {'lat': 64.2539, 'lon': -15.2082},
#    'dt': 1569438627,
#    'id': 2630299,
#    'main': {'humidity': 100,
#             'pressure': 997,
#             'temp': 10,
#             'temp_max': 10,
#             'temp_min': 10},
#    'name': 'Hofn',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'IS'},
#    'weather': [{'description': 'shower rain',
#                 'icon': '09n',
#                 'id': 521,
#                 'main': 'Rain'},
#                {'description': 'mist',
#                 'icon': '50n',
#                 'id': 701,
#                 'main': 'Mist'}],
#    'wind': {'deg': 260, 'speed': 2.6}}],
#  [{'clouds': {'all': 0},
#    'coord': {'lat': 55.2627, 'lon': 23.4828},
#    'dt': 1569438560,
#    'id': 600962,
#    'main': {'humidity': 70,
#             'pressure': 1013,
#             'temp': 8,
#             'temp_max': 8,
#             'temp_min': 8},
#    'name': 'Ariogala',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'LT'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01n',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 100, 'speed': 3.1}}],
#  [{'clouds': {'all': 98},
#    'coord': {'lat': 60.0603, 'lon': 69.9229},
#    'dt': 1569438584,
#    'id': 1506268,
#    'main': {'grnd_level': 1001.3,
#             'humidity': 74,
#             'pressure': 1006.31,
#             'sea_level': 1006.31,
#             'temp': 2.35,
#             'temp_max': 2.35,
#             'temp_min': 2.35},
#    'name': 'Gornopravdinsk',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'RU'},
#    'weather': [{'description': 'overcast clouds',
#                 'icon': '04n',
#                 'id': 804,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 231.796, 'speed': 4.46}}],
#  [{'clouds': {'all': 0},
#    'coord': {'lat': 19.1031, 'lon': 37.3312},
#    'dt': 1569438544,
#    'id': 367544,
#    'main': {'grnd_level': 936.81,
#             'humidity': 41,
#             'pressure': 1007.65,
#             'sea_level': 1007.65,
#             'temp': 29.25,
#             'temp_max': 29.25,
#             'temp_min': 29.25},
#    'name': 'Sawakin',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'SD'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01n',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 50.001, 'speed': 0.11}}],
#  [{'clouds': {'all': 32},
#    'coord': {'lat': -25.408, 'lon': -70.4859},
#    'dt': 1569438690,
#    'id': 3870243,
#    'main': {'grnd_level': 970.28,
#             'humidity': 66,
#             'pressure': 1014.97,
#             'sea_level': 1014.97,
#             'temp': 13.45,
#             'temp_max': 13.45,
#             'temp_min': 13.45},
#    'name': 'Taltal',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'CL'},
#    'weather': [{'description': 'scattered clouds',
#                 'icon': '03d',
#                 'id': 802,
#                 'main': 'Clouds'}],
#    'wind': {'deg': 284.279, 'speed': 3.38}}],
#  [{'clouds': {'all': 0},
#    'coord': {'lat': -21.422, 'lon': 25.588},
#    'dt': 1569438547,
#    'id': 933535,
#    'main': {'grnd_level': 910.74,
#             'humidity': 57,
#             'pressure': 1026.17,
#             'sea_level': 1026.17,
#             'temp': 15.25,
#             'temp_max': 15.25,
#             'temp_min': 15.25},
#    'name': 'Letlhakane',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'BW'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01n',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 96.876, 'speed': 7.74}}],
#  [{'clouds': {'all': 0},
#    'coord': {'lat': 53.8602, 'lon': 120.8781},
#    'dt': 1569438590,
#    'id': 2027806,
#    'main': {'grnd_level': 922.41,
#             'humidity': 86,
#             'pressure': 1018.91,
#             'sea_level': 1018.91,
#             'temp': 4.05,
#             'temp_max': 4.05,
#             'temp_min': 4.05},
#    'name': 'Amazar',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': 'RU'},
#    'weather': [{'description': 'clear sky',
#                 'icon': '01n',
#                 'id': 800,
#                 'main': 'Clear'}],
#    'wind': {'deg': 75.647, 'speed': 0.66}}]]

# %%
summary = ["clouds.all", "sys.country", "dt", "main.temp", "main.humidity", "coord.lat", "coord.lon", "main.temp_max", "wind.speed"]
cities = cities_dft['City'].values

# Create a Pandas DataFrame with the results
data = [response(*summary) for response in weather_data]
column_names = ['Cloudiness', 'Country', 'Time', 'Temperature', 'Humidity', 'Lattitude', 'Longitude', 'Max Temp', 'Wind Speed']
weather_data = pd.DataFrame(data, index=cities, columns=column_names)
weather_data.head()

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#params = {
#    "City": target_coordinates,
#    "Cloudiness": target_search,
#    "Country": target_radius,
#    "Date": target_type,
#    "Humidity": target_coordinates,
#    "Lat": target_search,
#    "Lng": target_radius,
#    "Max Temp": target_type,
#    "Wind Speed": target_type
#}

# %%
settings = {"units": "metric", "appid": api_key}

# %%
current_weather_paris = owm.get_current("deputatskiy", **settings)
print(f"Current weather object for Paris: {current_weather_paris}.")

# %%
summary = ["name", "clouds.all", "sys.country", "main.temp", "main.humidity", "coord.lat", "coord.lon", "main.temp_max", "wind.speed" ]

data = current_weather_paris(*summary)
print(f"The current weather summary for Paris is: {data}.")

# %%
units = ["metric"]

# set up list to hold two different temperatures
temperatures = []

# loop throught the list of units and append them to temperatures list
for city in cities:
    # Build query URL based on current element in units
    query_url = url + "appid=" + api_key + "&q=" + "&units=" + unit

    # Get weather data
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()

    # Get temperature from JSON response
    temperature = weather_json["main"]["temp"]

    temperatures.append(temperature)

# Report temperatures by accessing each element in the list
print(
    f"The temperature in Bujumbura is {temperatures[0]}C or {temperatures[1]}F.")

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
