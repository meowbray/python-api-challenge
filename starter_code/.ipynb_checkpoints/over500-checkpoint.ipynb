# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm
import openweathermapy as ow
import json
import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %%
cities_df = pd.DataFrame(cities)

# %%
cities_df.columns = ['City']
cities_df.head()
# Out:
#              City
# 0   belushya guba
# 1  saint-philippe
# 2         ushuaia
# 3      bredasdorp
# 4         rikitea

# %%
export_csv = cities_df.to_csv('output_data/cities.csv', encoding='utf-8', index=False)

# %%
cities_dft = pd.read_csv('output_data/cities.csv')
cities_dft.head()
# Out:
#              City
# 0   belushya guba
# 1  saint-philippe
# 2         ushuaia
# 3      bredasdorp
# 4         rikitea

# %%
cities_dft.reset_index(drop=True, inplace=True)

# %%
settings = {"appid": api_key, "units": "metric"}

# %%
units = ["metric"]

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
query_url = url + "appid=" + api_key + "&q=" + city

# %%
print(requests.get(query_url))
# Out:
# <Response [200]>

# %%
keys = ["clouds.all", "sys.country", "dt", "main.temp", "main.humidity", "coord.lat", "coord.lon", "main.temp_max", "wind.speed"]

# %%
n = 0
keys = ["clouds.all", "sys.country", "dt", "main.temp", "main.humidity", "coord.lat", "coord.lon", "main.temp_max", "wind.speed"]
weather_data = []
for index, row in cities_df.iterrows():
    n += 1
    time.sleep(1)
    weather_data.append(owm.find_city(row[0], **settings)(keys))
    print(f"City number {n} is, {row}")
#time.sleep(1)
#    if weather_data['cod'] == "404":
#        print(f"City, is not available")
# Out:
# City number 1 is, City    belushya guba
# Name: 0, dtype: object
# City number 2 is, City    saint-philippe
# Name: 1, dtype: object
# City number 3 is, City    ushuaia
# Name: 2, dtype: object
# City number 4 is, City    bredasdorp
# Name: 3, dtype: object
# City number 5 is, City    rikitea
# Name: 4, dtype: object
# City number 6 is, City    georgetown
# Name: 5, dtype: object
# City number 7 is, City    dikson
# Name: 6, dtype: object
# City number 8 is, City    rawson
# Name: 7, dtype: object
# City number 9 is, City    atuona
# Name: 8, dtype: object
# City number 10 is, City    chuy
# Name: 9, dtype: object
# City number 11 is, City    ibirama
# Name: 10, dtype: object
# City number 12 is, City    hay river
# Name: 11, dtype: object
# City number 13 is, City    busselton
# Name: 12, dtype: object
# City number 14 is, City    dmitrov
# Name: 13, dtype: object
# City number 15 is, City    amderma
# Name: 14, dtype: object
# City number 16 is, City    jamestown
# Name: 15, dtype: object
# City number 17 is, City    buraydah
# Name: 16, dtype: object
# City number 18 is, City    arraial do cabo
# Name: 17, dtype: object
# City number 19 is, City    sao francisco de paula
# Name: 18, dtype: object
# City number 20 is, City    souillac
# Name: 19, dtype: object
# City number 21 is, City    bandarbeyla
# Name: 20, dtype: object
# City number 22 is, City    chokurdakh
# Name: 21, dtype: object
# City number 23 is, City    avera
# Name: 22, dtype: object
# City number 24 is, City    taolanaro
# Name: 23, dtype: object
# City number 25 is, City    futtsu
# Name: 24, dtype: object
# City number 26 is, City    airai
# Name: 25, dtype: object
# City number 27 is, City    basco
# Name: 26, dtype: object
# City number 28 is, City    wad madani
# Name: 27, dtype: object
# City number 29 is, City    sorong
# Name: 28, dtype: object
# City number 30 is, City    khatanga
# Name: 29, dtype: object
# City number 31 is, City    bethel
# Name: 30, dtype: object
# City number 32 is, City    mlowo
# Name: 31, dtype: object
# City number 33 is, City    qaanaaq
# Name: 32, dtype: object
# City number 34 is, City    dunda
# Name: 33, dtype: object
# City number 35 is, City    leningradskiy
# Name: 34, dtype: object
# City number 36 is, City    avarua
# Name: 35, dtype: object
# City number 37 is, City    kandrian
# Name: 36, dtype: object
# City number 38 is, City    lata
# Name: 37, dtype: object
# City number 39 is, City    kapaa
# Name: 38, dtype: object
# City number 40 is, City    ponta do sol
# Name: 39, dtype: object
# City number 41 is, City    riviere-au-renard
# Name: 40, dtype: object
# City number 42 is, City    snina
# Name: 41, dtype: object
# City number 43 is, City    gubkinskiy
# Name: 42, dtype: object
# City number 44 is, City    wielun
# Name: 43, dtype: object
# City number 45 is, City    cape town
# Name: 44, dtype: object
# City number 46 is, City    new norfolk
# Name: 45, dtype: object
# City number 47 is, City    talnakh
# Name: 46, dtype: object
# City number 48 is, City    victoria
# Name: 47, dtype: object
# City number 49 is, City    walla walla
# Name: 48, dtype: object
# City number 50 is, City    torbay
# Name: 49, dtype: object
# City number 51 is, City    nguiu
# Name: 50, dtype: object
# City number 52 is, City    mataura
# Name: 51, dtype: object
# City number 53 is, City    chapais
# Name: 52, dtype: object
# City number 54 is, City    tura
# Name: 53, dtype: object
# City number 55 is, City    valparaiso
# Name: 54, dtype: object
# City number 56 is, City    krasnyy chikoy
# Name: 55, dtype: object
# City number 57 is, City    bluff
# Name: 56, dtype: object
# City number 58 is, City    puerto ayora
# Name: 57, dtype: object
# City number 59 is, City    zhoucheng
# Name: 58, dtype: object
# City number 60 is, City    crestview
# Name: 59, dtype: object
# City number 61 is, City    vaini
# Name: 60, dtype: object
# City number 62 is, City    hobart
# Name: 61, dtype: object
# City number 63 is, City    mayor pablo lagerenza
# Name: 62, dtype: object
# City number 64 is, City    punta arenas
# Name: 63, dtype: object
# City number 65 is, City    nemuro
# Name: 64, dtype: object
# City number 66 is, City    sebring
# Name: 65, dtype: object
# City number 67 is, City    attawapiskat
# Name: 66, dtype: object
# City number 68 is, City    kruisfontein
# Name: 67, dtype: object
# City number 69 is, City    rabat
# Name: 68, dtype: object
# City number 70 is, City    vila
# Name: 69, dtype: object
# City number 71 is, City    hambantota
# Name: 70, dtype: object
# City number 72 is, City    maxixe
# Name: 71, dtype: object
# City number 73 is, City    galiwinku
# Name: 72, dtype: object
# City number 74 is, City    port alfred
# Name: 73, dtype: object
# City number 75 is, City    kahului
# Name: 74, dtype: object
# City number 76 is, City    hithadhoo
# Name: 75, dtype: object
# City number 77 is, City    gasa
# Name: 76, dtype: object
# City number 78 is, City    saryshagan
# Name: 77, dtype: object
# City number 79 is, City    albany
# Name: 78, dtype: object
# City number 80 is, City    yellowknife
# Name: 79, dtype: object
# City number 81 is, City    znamenskoye
# Name: 80, dtype: object
# City number 82 is, City    namatanai
# Name: 81, dtype: object
# City number 83 is, City    omboue
# Name: 82, dtype: object
# City number 84 is, City    trat
# Name: 83, dtype: object
# City number 85 is, City    turukhansk
# Name: 84, dtype: object
# City number 86 is, City    bambous virieux
# Name: 85, dtype: object
# City number 87 is, City    mehamn
# Name: 86, dtype: object
# City number 88 is, City    lydenburg
# Name: 87, dtype: object
# City number 89 is, City    barrow
# Name: 88, dtype: object
# City number 90 is, City    butaritari
# Name: 89, dtype: object
# City number 91 is, City    hecun
# Name: 90, dtype: object
# City number 92 is, City    hermanus
# Name: 91, dtype: object
# City number 93 is, City    novosokolniki
# Name: 92, dtype: object
# City number 94 is, City    ribeira grande
# Name: 93, dtype: object
# City number 95 is, City    warqla
# Name: 94, dtype: object
# City number 96 is, City    awbari
# Name: 95, dtype: object
# City number 97 is, City    torquay
# Name: 96, dtype: object
# City number 98 is, City    sorland
# Name: 97, dtype: object
# City number 99 is, City    thompson
# Name: 98, dtype: object
# City number 100 is, City    latur
# Name: 99, dtype: object
# City number 101 is, City    hilo
# Name: 100, dtype: object
# City number 102 is, City    koungheul
# Name: 101, dtype: object
# City number 103 is, City    saldanha
# Name: 102, dtype: object
# City number 104 is, City    kaitangata
# Name: 103, dtype: object
# City number 105 is, City    atasu
# Name: 104, dtype: object
# City number 106 is, City    pevek
# Name: 105, dtype: object
# City number 107 is, City    ambovombe
# Name: 106, dtype: object
# City number 108 is, City    ipora
# Name: 107, dtype: object
# City number 109 is, City    san jose
# Name: 108, dtype: object
# City number 110 is, City    wewak
# Name: 109, dtype: object
# City number 111 is, City    hasaki
# Name: 110, dtype: object
# City number 112 is, City    qaqortoq
# Name: 111, dtype: object
# City number 113 is, City    lompoc
# Name: 112, dtype: object
# City number 114 is, City    pisco
# Name: 113, dtype: object
# City number 115 is, City    tete
# Name: 114, dtype: object
# City number 116 is, City    tautira
# Name: 115, dtype: object
# City number 117 is, City    artyk
# Name: 116, dtype: object
# City number 118 is, City    varhaug
# Name: 117, dtype: object
# City number 119 is, City    barentsburg
# Name: 118, dtype: object
# City number 120 is, City    yamada
# Name: 119, dtype: object
# City number 121 is, City    viedma
# Name: 120, dtype: object
# City number 122 is, City    maumere
# Name: 121, dtype: object
# City number 123 is, City    charyshskoye
# Name: 122, dtype: object
# City number 124 is, City    acapulco
# Name: 123, dtype: object
# City number 125 is, City    zhigansk
# Name: 124, dtype: object
# City number 126 is, City    richards bay
# Name: 125, dtype: object
# City number 127 is, City    cabo san lucas
# Name: 126, dtype: object
# City number 128 is, City    vrbove
# Name: 127, dtype: object
# City number 129 is, City    comodoro rivadavia
# Name: 128, dtype: object
# City number 130 is, City    luderitz
# Name: 129, dtype: object
# City number 131 is, City    mersing
# Name: 130, dtype: object
# City number 132 is, City    nizhneyansk
# Name: 131, dtype: object
# City number 133 is, City    umzimvubu
# Name: 132, dtype: object
# City number 134 is, City    cherskiy
# Name: 133, dtype: object
# City number 135 is, City    grand river south east
# Name: 134, dtype: object
# City number 136 is, City    vaitupu
# Name: 135, dtype: object
# City number 137 is, City    suncuius
# Name: 136, dtype: object
# City number 138 is, City    maniitsoq
# Name: 137, dtype: object
# City number 139 is, City    nikolskoye
# Name: 138, dtype: object
# City number 140 is, City    havoysund
# Name: 139, dtype: object
# City number 141 is, City    gorkovskoye
# Name: 140, dtype: object
# City number 142 is, City    mys shmidta
# Name: 141, dtype: object
# City number 143 is, City    fukue
# Name: 142, dtype: object
# City number 144 is, City    puerto maldonado
# Name: 143, dtype: object
# City number 145 is, City    tuktoyaktuk
# Name: 144, dtype: object
# City number 146 is, City    sao filipe
# Name: 145, dtype: object
# City number 147 is, City    jega
# Name: 146, dtype: object
# City number 148 is, City    sukhodol
# Name: 147, dtype: object
# City number 149 is, City    dobeln
# Name: 148, dtype: object
# City number 150 is, City    mackay
# Name: 149, dtype: object
# City number 151 is, City    upernavik
# Name: 150, dtype: object
# City number 152 is, City    tasiilaq
# Name: 151, dtype: object
# City number 153 is, City    spencer
# Name: 152, dtype: object
# City number 154 is, City    katsiveli
# Name: 153, dtype: object
# City number 155 is, City    utiroa
# Name: 154, dtype: object
# City number 156 is, City    laerdalsoyri
# Name: 155, dtype: object
# City number 157 is, City    stornoway
# Name: 156, dtype: object
# City number 158 is, City    illoqqortoormiut
# Name: 157, dtype: object
# City number 159 is, City    saint george
# Name: 158, dtype: object
# City number 160 is, City    axim
# Name: 159, dtype: object
# City number 161 is, City    vila franca do campo
# Name: 160, dtype: object
# City number 162 is, City    port blair
# Name: 161, dtype: object
# City number 163 is, City    bubaque
# Name: 162, dtype: object
# City number 164 is, City    mount isa
# Name: 163, dtype: object
# City number 165 is, City    provideniya
# Name: 164, dtype: object
# City number 166 is, City    kavieng
# Name: 165, dtype: object
# City number 167 is, City    homer
# Name: 166, dtype: object
# City number 168 is, City    kodiak
# Name: 167, dtype: object
# City number 169 is, City    te anau
# Name: 168, dtype: object
# City number 170 is, City    kuruman
# Name: 169, dtype: object
# City number 171 is, City    san patricio
# Name: 170, dtype: object
# City number 172 is, City    caceres
# Name: 171, dtype: object
# City number 173 is, City    arzgir
# Name: 172, dtype: object
# City number 174 is, City    cockburn town
# Name: 173, dtype: object
# City number 175 is, City    itarema
# Name: 174, dtype: object
# City number 176 is, City    lasa
# Name: 175, dtype: object
# City number 177 is, City    ruatoria
# Name: 176, dtype: object
# City number 178 is, City    tiksi
# Name: 177, dtype: object
# City number 179 is, City    whitianga
# Name: 178, dtype: object
# City number 180 is, City    saskylakh
# Name: 179, dtype: object
# City number 181 is, City    carnarvon
# Name: 180, dtype: object
# City number 182 is, City    terenos
# Name: 181, dtype: object
# City number 183 is, City    ola
# Name: 182, dtype: object
# City number 184 is, City    arcata
# Name: 183, dtype: object
# City number 185 is, City    ylojarvi
# Name: 184, dtype: object
# City number 186 is, City    port hardy
# Name: 185, dtype: object
# City number 187 is, City    inirida
# Name: 186, dtype: object
# City number 188 is, City    nata
# Name: 187, dtype: object
# City number 189 is, City    puerto gaitan
# Name: 188, dtype: object
# City number 190 is, City    manavalakurichi
# Name: 189, dtype: object
# City number 191 is, City    ishigaki
# Name: 190, dtype: object
# City number 192 is, City    shenjiamen
# Name: 191, dtype: object
# City number 193 is, City    kyrylivka
# Name: 192, dtype: object
# City number 194 is, City    ostrovnoy
# Name: 193, dtype: object
# City number 195 is, City    ilulissat
# Name: 194, dtype: object
# City number 196 is, City    yulara
# Name: 195, dtype: object
# City number 197 is, City    labuhan
# Name: 196, dtype: object
# City number 198 is, City    tecolutla
# Name: 197, dtype: object
# City number 199 is, City    castro
# Name: 198, dtype: object
# City number 200 is, City    saleaula
# Name: 199, dtype: object
# City number 201 is, City    geresk
# Name: 200, dtype: object
# City number 202 is, City    henties bay
# Name: 201, dtype: object
# City number 203 is, City    akdagmadeni
# Name: 202, dtype: object
# City number 204 is, City    fairbanks
# Name: 203, dtype: object
# City number 205 is, City    beloha
# Name: 204, dtype: object
# City number 206 is, City    alyangula
# Name: 205, dtype: object
# City number 207 is, City    hualmay
# Name: 206, dtype: object
# City number 208 is, City    parras
# Name: 207, dtype: object
# City number 209 is, City    karkaralinsk
# Name: 208, dtype: object
# City number 210 is, City    roma
# Name: 209, dtype: object
# City number 211 is, City    norman wells
# Name: 210, dtype: object
# City number 212 is, City    ketchikan
# Name: 211, dtype: object
# City number 213 is, City    dharchula
# Name: 212, dtype: object
# City number 214 is, City    isangel
# Name: 213, dtype: object
# City number 215 is, City    surt
# Name: 214, dtype: object
# City number 216 is, City    tessalit
# Name: 215, dtype: object
# City number 217 is, City    kalengwa
# Name: 216, dtype: object
# City number 218 is, City    sawakin
# Name: 217, dtype: object
# City number 219 is, City    pilar
# Name: 218, dtype: object
# City number 220 is, City    nanortalik
# Name: 219, dtype: object
# City number 221 is, City    denpasar
# Name: 220, dtype: object
# City number 222 is, City    maridi
# Name: 221, dtype: object
# City number 223 is, City    alekseyevsk
# Name: 222, dtype: object
# City number 224 is, City    lagoa
# Name: 223, dtype: object
# City number 225 is, City    pangody
# Name: 224, dtype: object
# City number 226 is, City    egvekinot
# Name: 225, dtype: object
# City number 227 is, City    altay
# Name: 226, dtype: object
# City number 228 is, City    san juan
# Name: 227, dtype: object
# City number 229 is, City    aflu
# Name: 228, dtype: object
# City number 230 is, City    chara
# Name: 229, dtype: object
# City number 231 is, City    bathsheba
# Name: 230, dtype: object
# City number 232 is, City    olavarria
# Name: 231, dtype: object
# City number 233 is, City    canon city
# Name: 232, dtype: object
# City number 234 is, City    vanimo
# Name: 233, dtype: object
# City number 235 is, City    waynesboro
# Name: 234, dtype: object
# City number 236 is, City    muros
# Name: 235, dtype: object
# City number 237 is, City    fomboni
# Name: 236, dtype: object
# City number 238 is, City    patos
# Name: 237, dtype: object
# City number 239 is, City    mar del plata
# Name: 238, dtype: object
# City number 240 is, City    grand gaube
# Name: 239, dtype: object
# City number 241 is, City    catuday
# Name: 240, dtype: object
# City number 242 is, City    loa janan
# Name: 241, dtype: object
# City number 243 is, City    mahebourg
# Name: 242, dtype: object
# City number 244 is, City    padang
# Name: 243, dtype: object
# City number 245 is, City    nantucket
# Name: 244, dtype: object
# City number 246 is, City    itacoatiara
# Name: 245, dtype: object
# City number 247 is, City    mitsamiouli
# Name: 246, dtype: object
# City number 248 is, City    dingle
# Name: 247, dtype: object
# City number 249 is, City    dubbo
# Name: 248, dtype: object
# City number 250 is, City    anadyr
# Name: 249, dtype: object
# City number 251 is, City    dumas
# Name: 250, dtype: object
# City number 252 is, City    kamenskoye
# Name: 251, dtype: object
# City number 253 is, City    villa oliva
# Name: 252, dtype: object
# City number 254 is, City    pahrump
# Name: 253, dtype: object
# City number 255 is, City    ahuimanu
# Name: 254, dtype: object
# City number 256 is, City    beringovskiy
# Name: 255, dtype: object
# City number 257 is, City    manzhouli
# Name: 256, dtype: object
# City number 258 is, City    awash
# Name: 257, dtype: object
# City number 259 is, City    boffa
# Name: 258, dtype: object
# City number 260 is, City    khormuj
# Name: 259, dtype: object
# City number 261 is, City    vao
# Name: 260, dtype: object
# City number 262 is, City    santa maria
# Name: 261, dtype: object
# City number 263 is, City    taltal
# Name: 262, dtype: object
# City number 264 is, City    ixtapa
# Name: 263, dtype: object
# City number 265 is, City    adrar
# Name: 264, dtype: object
# City number 266 is, City    mont-dore
# Name: 265, dtype: object
# City number 267 is, City    klaksvik
# Name: 266, dtype: object
# City number 268 is, City    bolungarvik
# Name: 267, dtype: object
# City number 269 is, City    narsaq
# Name: 268, dtype: object
# City number 270 is, City    ancud
# Name: 269, dtype: object
# City number 271 is, City    keshorai patan
# Name: 270, dtype: object
# City number 272 is, City    tucuman
# Name: 271, dtype: object
# City number 273 is, City    rocha
# Name: 272, dtype: object
# City number 274 is, City    oktyabrskoye
# Name: 273, dtype: object
# City number 275 is, City    worthing
# Name: 274, dtype: object
# City number 276 is, City    makakilo city
# Name: 275, dtype: object
# City number 277 is, City    urengoy
# Name: 276, dtype: object
# City number 278 is, City    tsihombe
# Name: 277, dtype: object
# City number 279 is, City    harper
# Name: 278, dtype: object
# City number 280 is, City    kibre mengist
# Name: 279, dtype: object
# City number 281 is, City    evensk
# Name: 280, dtype: object
# City number 282 is, City    nome
# Name: 281, dtype: object
# City number 283 is, City    samarai
# Name: 282, dtype: object
# City number 284 is, City    teknaf
# Name: 283, dtype: object
# City number 285 is, City    naze
# Name: 284, dtype: object
# City number 286 is, City    udachnyy
# Name: 285, dtype: object
# City number 287 is, City    camacha
# Name: 286, dtype: object
# City number 288 is, City    nicolas bravo
# Name: 287, dtype: object
# City number 289 is, City    la ronge
# Name: 288, dtype: object
# City number 290 is, City    coripata
# Name: 289, dtype: object
# City number 291 is, City    iquitos
# Name: 290, dtype: object
# City number 292 is, City    berlevag
# Name: 291, dtype: object
# City number 293 is, City    okhotsk
# Name: 292, dtype: object
# City number 294 is, City    solnechnyy
# Name: 293, dtype: object
# City number 295 is, City    pangnirtung
# Name: 294, dtype: object
# City number 296 is, City    koga
# Name: 295, dtype: object
# City number 297 is, City    praxedis guerrero
# Name: 296, dtype: object
# City number 298 is, City    kangaatsiaq
# Name: 297, dtype: object
# City number 299 is, City    sur
# Name: 298, dtype: object
# City number 300 is, City    bambanglipuro
# Name: 299, dtype: object
# City number 301 is, City    port elizabeth
# Name: 300, dtype: object
# City number 302 is, City    santa cecilia
# Name: 301, dtype: object
# City number 303 is, City    grindavik
# Name: 302, dtype: object
# City number 304 is, City    lamu
# Name: 303, dtype: object
# City number 305 is, City    lorengau
# Name: 304, dtype: object
# City number 306 is, City    scarborough
# Name: 305, dtype: object
# City number 307 is, City    raudeberg
# Name: 306, dtype: object
# City number 308 is, City    urumqi
# Name: 307, dtype: object
# City number 309 is, City    anchorage
# Name: 308, dtype: object
# City number 310 is, City    salinas
# Name: 309, dtype: object
# City number 311 is, City    lebu
# Name: 310, dtype: object
# City number 312 is, City    lulea
# Name: 311, dtype: object
# City number 313 is, City    price
# Name: 312, dtype: object
# City number 314 is, City    say
# Name: 313, dtype: object
# City number 315 is, City    baghdad
# Name: 314, dtype: object
# City number 316 is, City    neiafu
# Name: 315, dtype: object
# City number 317 is, City    charleston
# Name: 316, dtype: object
# City number 318 is, City    ojhar
# Name: 317, dtype: object
# City number 319 is, City    mangai
# Name: 318, dtype: object
# City number 320 is, City    divnomorskoye
# Name: 319, dtype: object
# City number 321 is, City    gushikawa
# Name: 320, dtype: object
# City number 322 is, City    dabat
# Name: 321, dtype: object
# City number 323 is, City    fortuna
# Name: 322, dtype: object
# City number 324 is, City    omsukchan
# Name: 323, dtype: object
# City number 325 is, City    san carlos de bariloche
# Name: 324, dtype: object
# City number 326 is, City    baiao
# Name: 325, dtype: object
# City number 327 is, City    kholodnyy
# Name: 326, dtype: object
# City number 328 is, City    el campo
# Name: 327, dtype: object
# City number 329 is, City    keuruu
# Name: 328, dtype: object
# City number 330 is, City    ruidoso
# Name: 329, dtype: object
# City number 331 is, City    longyearbyen
# Name: 330, dtype: object
# City number 332 is, City    berezovyy
# Name: 331, dtype: object
# City number 333 is, City    gidam
# Name: 332, dtype: object
# City number 334 is, City    cuamba
# Name: 333, dtype: object
# City number 335 is, City    severo-yeniseyskiy
# Name: 334, dtype: object
# City number 336 is, City    ca mau
# Name: 335, dtype: object
# City number 337 is, City    djambala
# Name: 336, dtype: object
# City number 338 is, City    maracacume
# Name: 337, dtype: object
# City number 339 is, City    belmonte
# Name: 338, dtype: object
# City number 340 is, City    haines junction
# Name: 339, dtype: object
# City number 341 is, City    lavrentiya
# Name: 340, dtype: object
# City number 342 is, City    bure
# Name: 341, dtype: object
# City number 343 is, City    lusambo
# Name: 342, dtype: object
# City number 344 is, City    dekoa
# Name: 343, dtype: object
# City number 345 is, City    sampit
# Name: 344, dtype: object
# City number 346 is, City    east london
# Name: 345, dtype: object
# City number 347 is, City    veraval
# Name: 346, dtype: object
# City number 348 is, City    lodja
# Name: 347, dtype: object
# City number 349 is, City    aswan
# Name: 348, dtype: object
# City number 350 is, City    nawabshah
# Name: 349, dtype: object
# City number 351 is, City    eureka
# Name: 350, dtype: object
# City number 352 is, City    sudova vyshnya
# Name: 351, dtype: object
# City number 353 is, City    touros
# Name: 352, dtype: object
# City number 354 is, City    sitka
# Name: 353, dtype: object
# City number 355 is, City    lubango
# Name: 354, dtype: object
# City number 356 is, City    bosaso
# Name: 355, dtype: object
# City number 357 is, City    general roca
# Name: 356, dtype: object
# City number 358 is, City    kaniama
# Name: 357, dtype: object
# City number 359 is, City    alofi
# Name: 358, dtype: object
# City number 360 is, City    sola
# Name: 359, dtype: object
# City number 361 is, City    mudanya
# Name: 360, dtype: object
# City number 362 is, City    severo-kurilsk
# Name: 361, dtype: object
# City number 363 is, City    faanui
# Name: 362, dtype: object
# City number 364 is, City    murovani kurylivtsi
# Name: 363, dtype: object
# City number 365 is, City    khonuu
# Name: 364, dtype: object
# City number 366 is, City    tsaratanana
# Name: 365, dtype: object
# City number 367 is, City    nanning
# Name: 366, dtype: object
# City number 368 is, City    zarate
# Name: 367, dtype: object
# City number 369 is, City    bolgar
# Name: 368, dtype: object
# City number 370 is, City    araouane
# Name: 369, dtype: object
# City number 371 is, City    filadelfia
# Name: 370, dtype: object
# City number 372 is, City    korla
# Name: 371, dtype: object
# City number 373 is, City    thunder bay
# Name: 372, dtype: object
# City number 374 is, City    esso
# Name: 373, dtype: object
# City number 375 is, City    havre
# Name: 374, dtype: object
# City number 376 is, City    guilin
# Name: 375, dtype: object
# City number 377 is, City    portland
# Name: 376, dtype: object
# City number 378 is, City    wieliczka
# Name: 377, dtype: object
# City number 379 is, City    acucena
# Name: 378, dtype: object
# City number 380 is, City    olonets
# Name: 379, dtype: object
# City number 381 is, City    shablykino
# Name: 380, dtype: object
# City number 382 is, City    constantine
# Name: 381, dtype: object
# City number 383 is, City    toamasina
# Name: 382, dtype: object
# City number 384 is, City    san policarpo
# Name: 383, dtype: object
# City number 385 is, City    hommelvik
# Name: 384, dtype: object
# City number 386 is, City    desaguadero
# Name: 385, dtype: object
# City number 387 is, City    yar-sale
# Name: 386, dtype: object
# City number 388 is, City    nishihara
# Name: 387, dtype: object
# City number 389 is, City    belaya gora
# Name: 388, dtype: object
# City number 390 is, City    hauknes
# Name: 389, dtype: object
# City number 391 is, City    poum
# Name: 390, dtype: object
# City number 392 is, City    andros
# Name: 391, dtype: object
# City number 393 is, City    aklavik
# Name: 392, dtype: object
# City number 394 is, City    eyl
# Name: 393, dtype: object
# City number 395 is, City    aguimes
# Name: 394, dtype: object
# City number 396 is, City    tacoronte
# Name: 395, dtype: object
# City number 397 is, City    paka
# Name: 396, dtype: object
# City number 398 is, City    kuusamo
# Name: 397, dtype: object
# City number 399 is, City    port lincoln
# Name: 398, dtype: object
# City number 400 is, City    puerto suarez
# Name: 399, dtype: object
# City number 401 is, City    jiddah
# Name: 400, dtype: object
# City number 402 is, City    luanda
# Name: 401, dtype: object
# City number 403 is, City    kamenka
# Name: 402, dtype: object
# City number 404 is, City    clyde river
# Name: 403, dtype: object
# City number 405 is, City    bandarban
# Name: 404, dtype: object
# City number 406 is, City    plettenberg bay
# Name: 405, dtype: object
# City number 407 is, City    antalaha
# Name: 406, dtype: object
# City number 408 is, City    guerrero negro
# Name: 407, dtype: object
# City number 409 is, City    tecpan
# Name: 408, dtype: object
# City number 410 is, City    lianzhou
# Name: 409, dtype: object
# City number 411 is, City    khuzhir
# Name: 410, dtype: object
# City number 412 is, City    strezhevoy
# Name: 411, dtype: object
# City number 413 is, City    coihaique
# Name: 412, dtype: object
# City number 414 is, City    grand centre
# Name: 413, dtype: object
# City number 415 is, City    gazanjyk
# Name: 414, dtype: object
# City number 416 is, City    general pico
# Name: 415, dtype: object
# City number 417 is, City    nouadhibou
# Name: 416, dtype: object
# City number 418 is, City    matara
# Name: 417, dtype: object
# City number 419 is, City    slave lake
# Name: 418, dtype: object
# City number 420 is, City    baruun-urt
# Name: 419, dtype: object
# City number 421 is, City    zarand
# Name: 420, dtype: object
# City number 422 is, City    vardo
# Name: 421, dtype: object
# City number 423 is, City    phan rang
# Name: 422, dtype: object
# City number 424 is, City    sentyabrskiy
# Name: 423, dtype: object
# City number 425 is, City    thinadhoo
# Name: 424, dtype: object
# City number 426 is, City    indian head
# Name: 425, dtype: object
# City number 427 is, City    codrington
# Name: 426, dtype: object
# City number 428 is, City    karratha
# Name: 427, dtype: object
# City number 429 is, City    solovetskiy
# Name: 428, dtype: object
# City number 430 is, City    sompeta
# Name: 429, dtype: object
# City number 431 is, City    acari
# Name: 430, dtype: object
# City number 432 is, City    namanga
# Name: 431, dtype: object
# City number 433 is, City    olafsvik
# Name: 432, dtype: object
# City number 434 is, City    doctor pedro p. pena
# Name: 433, dtype: object
# City number 435 is, City    fengrun
# Name: 434, dtype: object
# City number 436 is, City    hami
# Name: 435, dtype: object
# City number 437 is, City    valdivia
# Name: 436, dtype: object
# City number 438 is, City    riyadh
# Name: 437, dtype: object
# City number 439 is, City    saint pete beach
# Name: 438, dtype: object
# City number 440 is, City    hervey bay
# Name: 439, dtype: object
# City number 441 is, City    buala
# Name: 440, dtype: object
# City number 442 is, City    sangar
# Name: 441, dtype: object
# City number 443 is, City    takestan
# Name: 442, dtype: object
# City number 444 is, City    kabansk
# Name: 443, dtype: object
# City number 445 is, City    half moon bay
# Name: 444, dtype: object
# City number 446 is, City    hofn
# Name: 445, dtype: object
# City number 447 is, City    doka
# Name: 446, dtype: object
# City number 448 is, City    panaba
# Name: 447, dtype: object
# City number 449 is, City    sasovo
# Name: 448, dtype: object
# City number 450 is, City    loandjili
# Name: 449, dtype: object
# City number 451 is, City    panjab
# Name: 450, dtype: object
# City number 452 is, City    bonavista
# Name: 451, dtype: object
# City number 453 is, City    marcona
# Name: 452, dtype: object
# City number 454 is, City    remontnoye
# Name: 453, dtype: object
# City number 455 is, City    goundam
# Name: 454, dtype: object
# City number 456 is, City    cairns
# Name: 455, dtype: object
# City number 457 is, City    stephenville crossing
# Name: 456, dtype: object
# City number 458 is, City    chagda
# Name: 457, dtype: object
# City number 459 is, City    manta
# Name: 458, dtype: object
# City number 460 is, City    kutum
# Name: 459, dtype: object
# City number 461 is, City    hamilton
# Name: 460, dtype: object
# City number 462 is, City    raga
# Name: 461, dtype: object
# City number 463 is, City    tumannyy
# Name: 462, dtype: object
# City number 464 is, City    la paz
# Name: 463, dtype: object
# City number 465 is, City    ambositra
# Name: 464, dtype: object
# City number 466 is, City    ayan
# Name: 465, dtype: object
# City number 467 is, City    fort nelson
# Name: 466, dtype: object
# City number 468 is, City    lagos
# Name: 467, dtype: object
# City number 469 is, City    vostok
# Name: 468, dtype: object
# City number 470 is, City    atambua
# Name: 469, dtype: object
# City number 471 is, City    howard springs
# Name: 470, dtype: object
# City number 472 is, City    barcelos
# Name: 471, dtype: object
# City number 473 is, City    aykhal
# Name: 472, dtype: object
# City number 474 is, City    teguise
# Name: 473, dtype: object
# City number 475 is, City    los llanos de aridane
# Name: 474, dtype: object
# City number 476 is, City    quatre cocos
# Name: 475, dtype: object
# City number 477 is, City    mujiayingzi
# Name: 476, dtype: object
# City number 478 is, City    emerald
# Name: 477, dtype: object
# City number 479 is, City    flinders
# Name: 478, dtype: object
# City number 480 is, City    trenton
# Name: 479, dtype: object
# City number 481 is, City    mount gambier
# Name: 480, dtype: object
# City number 482 is, City    sri aman
# Name: 481, dtype: object
# City number 483 is, City    ziarat
# Name: 482, dtype: object
# City number 484 is, City    morehead
# Name: 483, dtype: object
# City number 485 is, City    sept-iles
# Name: 484, dtype: object
# City number 486 is, City    saint anthony
# Name: 485, dtype: object
# City number 487 is, City    nanchang
# Name: 486, dtype: object
# City number 488 is, City    haibowan
# Name: 487, dtype: object
# City number 489 is, City    fort morgan
# Name: 488, dtype: object
# City number 490 is, City    rayachoti
# Name: 489, dtype: object
# City number 491 is, City    wajid
# Name: 490, dtype: object
# City number 492 is, City    stavrovo
# Name: 491, dtype: object
# City number 493 is, City    kavaratti
# Name: 492, dtype: object
# City number 494 is, City    mabaruma
# Name: 493, dtype: object
# City number 495 is, City    kazachka
# Name: 494, dtype: object
# City number 496 is, City    barabinsk
# Name: 495, dtype: object
# City number 497 is, City    campos belos
# Name: 496, dtype: object
# City number 498 is, City    sambava
# Name: 497, dtype: object
# City number 499 is, City    houma
# Name: 498, dtype: object
# City number 500 is, City    mahibadhoo
# Name: 499, dtype: object
# City number 501 is, City    laguna
# Name: 500, dtype: object
# City number 502 is, City    phichit
# Name: 501, dtype: object
# City number 503 is, City    mutsamudu
# Name: 502, dtype: object
# City number 504 is, City    amga
# Name: 503, dtype: object
# City number 505 is, City    taurage
# Name: 504, dtype: object
# City number 506 is, City    acajutiba
# Name: 505, dtype: object
# City number 507 is, City    sao joao da barra
# Name: 506, dtype: object
# City number 508 is, City    carire
# Name: 507, dtype: object
# City number 509 is, City    margate
# Name: 508, dtype: object
# City number 510 is, City    vung tau
# Name: 509, dtype: object
# City number 511 is, City    palabuhanratu
# Name: 510, dtype: object
# City number 512 is, City    chicama
# Name: 511, dtype: object
# City number 513 is, City    cuxhaven
# Name: 512, dtype: object
# City number 514 is, City    gigmoto
# Name: 513, dtype: object
# City number 515 is, City    taoudenni
# Name: 514, dtype: object
# City number 516 is, City    ukiah
# Name: 515, dtype: object
# City number 517 is, City    torres
# Name: 516, dtype: object
# City number 518 is, City    amurzet
# Name: 517, dtype: object
# City number 519 is, City    shar
# Name: 518, dtype: object
# City number 520 is, City    alugan
# Name: 519, dtype: object
# City number 521 is, City    twentynine palms
# Name: 520, dtype: object
# City number 522 is, City    angoche
# Name: 521, dtype: object
# City number 523 is, City    kabelvag
# Name: 522, dtype: object
# City number 524 is, City    puerto escondido
# Name: 523, dtype: object
# City number 525 is, City    dicabisagan
# Name: 524, dtype: object
# City number 526 is, City    shimanovsk
# Name: 525, dtype: object
# City number 527 is, City    huruta
# Name: 526, dtype: object
# City number 528 is, City    cerro punta
# Name: 527, dtype: object
# City number 529 is, City    sibolga
# Name: 528, dtype: object
# City number 530 is, City    beyneu
# Name: 529, dtype: object
# City number 531 is, City    port-gentil
# Name: 530, dtype: object
# City number 532 is, City    kanchanaburi
# Name: 531, dtype: object
# City number 533 is, City    jacareacanga
# Name: 532, dtype: object
# City number 534 is, City    taganak
# Name: 533, dtype: object
# City number 535 is, City    keningau
# Name: 534, dtype: object
# City number 536 is, City    malakal
# Name: 535, dtype: object
# City number 537 is, City    nanton
# Name: 536, dtype: object
# City number 538 is, City    iskateley
# Name: 537, dtype: object
# City number 539 is, City    bacolod
# Name: 538, dtype: object
# City number 540 is, City    iqaluit
# Name: 539, dtype: object
# City number 541 is, City    mogadishu
# Name: 540, dtype: object
# City number 542 is, City    nieuw amsterdam
# Name: 541, dtype: object
# City number 543 is, City    baykit
# Name: 542, dtype: object
# City number 544 is, City    suluq
# Name: 543, dtype: object
# City number 545 is, City    namibe
# Name: 544, dtype: object
# City number 546 is, City    abonnema
# Name: 545, dtype: object
# City number 547 is, City    acarau
# Name: 546, dtype: object
# City number 548 is, City    daru
# Name: 547, dtype: object
# City number 549 is, City    pervomaysk
# Name: 548, dtype: object
# City number 550 is, City    montepuez
# Name: 549, dtype: object
# City number 551 is, City    lae
# Name: 550, dtype: object
# City number 552 is, City    farmington
# Name: 551, dtype: object
# City number 553 is, City    goure
# Name: 552, dtype: object
# City number 554 is, City    kainantu
# Name: 553, dtype: object
# City number 555 is, City    el wasta
# Name: 554, dtype: object
# City number 556 is, City    kolokani
# Name: 555, dtype: object
# City number 557 is, City    sooke
# Name: 556, dtype: object
# City number 558 is, City    pacific grove
# Name: 557, dtype: object
# City number 559 is, City    petropavlovsk-kamchatskiy
# Name: 558, dtype: object
# City number 560 is, City    coquimbo
# Name: 559, dtype: object
# City number 561 is, City    komsomolskiy
# Name: 560, dtype: object
# City number 562 is, City    likasi
# Name: 561, dtype: object
# City number 563 is, City    the valley
# Name: 562, dtype: object
# City number 564 is, City    athabasca
# Name: 563, dtype: object
# City number 565 is, City    yanan
# Name: 564, dtype: object
# City number 566 is, City    tynda
# Name: 565, dtype: object
# City number 567 is, City    ambilobe
# Name: 566, dtype: object
# City number 568 is, City    venice
# Name: 567, dtype: object
# City number 569 is, City    port hawkesbury
# Name: 568, dtype: object
# City number 570 is, City    esperance
# Name: 569, dtype: object
# City number 571 is, City    el cope
# Name: 570, dtype: object
# City number 572 is, City    moerai
# Name: 571, dtype: object
# City number 573 is, City    lovozero
# Name: 572, dtype: object
# City number 574 is, City    fuyang
# Name: 573, dtype: object
# City number 575 is, City    salalah
# Name: 574, dtype: object
# City number 576 is, City    maamba
# Name: 575, dtype: object
# City number 577 is, City    westport
# Name: 576, dtype: object
# City number 578 is, City    springbok
# Name: 577, dtype: object
# City number 579 is, City    srandakan
# Name: 578, dtype: object
# City number 580 is, City    alta floresta
# Name: 579, dtype: object
# City number 581 is, City    bengkulu
# Name: 580, dtype: object
# City number 582 is, City    karpinsk
# Name: 581, dtype: object
# City number 583 is, City    basoko
# Name: 582, dtype: object
# City number 584 is, City    kazalinsk
# Name: 583, dtype: object
# City number 585 is, City    mariental
# Name: 584, dtype: object
# City number 586 is, City    chulman
# Name: 585, dtype: object
# City number 587 is, City    buritis
# Name: 586, dtype: object
# City number 588 is, City    nara
# Name: 587, dtype: object
# City number 589 is, City    kupang
# Name: 588, dtype: object
# City number 590 is, City    talaya
# Name: 589, dtype: object
# City number 591 is, City    kiama
# Name: 590, dtype: object
# City number 592 is, City    natal
# Name: 591, dtype: object
# City number 593 is, City    moratuwa
# Name: 592, dtype: object
# City number 594 is, City    presidencia roque saenz pena
# Name: 593, dtype: object
# City number 595 is, City    yuzhno-yeniseyskiy
# Name: 594, dtype: object
# City number 596 is, City    garden city
# Name: 595, dtype: object
# City number 597 is, City    kawalu
# Name: 596, dtype: object
# City number 598 is, City    chernyshevskiy
# Name: 597, dtype: object
# City number 599 is, City    sarakhs
# Name: 598, dtype: object
# City number 600 is, City    ganderkesee
# Name: 599, dtype: object
# City number 601 is, City    trincomalee
# Name: 600, dtype: object
# City number 602 is, City    hlobyne
# Name: 601, dtype: object
# City number 603 is, City    cidreira
# Name: 602, dtype: object
# City number 604 is, City    xinqing
# Name: 603, dtype: object
# City number 605 is, City    marv dasht
# Name: 604, dtype: object
# City number 606 is, City    krasnovishersk
# Name: 605, dtype: object
# City number 607 is, City    ust-tsilma
# Name: 606, dtype: object
# City number 608 is, City    tapaua
# Name: 607, dtype: object
# City number 609 is, City    sibu
# Name: 608, dtype: object
# City number 610 is, City    quelimane
# Name: 609, dtype: object
# City number 611 is, City    grand forks
# Name: 610, dtype: object
# City number 612 is, City    kalianget
# Name: 611, dtype: object
# City number 613 is, City    barbar
# Name: 612, dtype: object

# %%
weather_data

# %%
#summary = ["clouds.all", "sys.country", "dt", "main.temp", "main.humidity", "coord.lat", "coord.lon", "main.temp_max", "wind.speed"]
cities = cities_dft['City'].values

# Create a Pandas DataFrame with the results
#data = [for row in weather_data]
column_names = ['Cloudiness', 'Country', 'Time', 'Temperature', 'Humidity', 'Lattitude', 'Longitude', 'Max Temp', 'Wind Speed']
weather_datat = pd.DataFrame(weather_data(index=cities, columns=column_names))
weather_datat.head()

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#params = {
#    "City": target_coordinates,
#    "Cloudiness": target_search,
#    "Country": target_radius,
#    "Date": target_type,
#    "Humidity": target_coordinates,
#    "Lat": target_search,
#    "Lng": target_radius,
#    "Max Temp": target_type,
#    "Wind Speed": target_type
#}

# %%
settings = {"units": "metric", "appid": api_key}

# %%
current_weather_paris = owm.get_current("deputatskiy", **settings)
print(f"Current weather object for Paris: {current_weather_paris}.")

# %%
summary = ["name", "clouds.all", "sys.country", "main.temp", "main.humidity", "coord.lat", "coord.lon", "main.temp_max", "wind.speed" ]

data = current_weather_paris(*summary)
print(f"The current weather summary for Paris is: {data}.")

# %%
units = ["metric"]

# set up list to hold two different temperatures
temperatures = []

# loop throught the list of units and append them to temperatures list
for city in cities:
    # Build query URL based on current element in units
    query_url = url + "appid=" + api_key + "&q=" + "&units=" + unit

    # Get weather data
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()

    # Get temperature from JSON response
    temperature = weather_json["main"]["temp"]

    temperatures.append(temperature)

# Report temperatures by accessing each element in the list
print(
    f"The temperature in Bujumbura is {temperatures[0]}C or {temperatures[1]}F.")

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
